# %%
# Setup ipython environment
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from matplotlib.pyplot import *
from numpy import *
from positive import *
# Out:
# (positive)>> Applying custom matplotlib settings.

# %%
#
# x: eta cos_the |a|
#
psf_coords = np.loadtxt("../sk/psf_phase_x.txt")
psf_y = np.loadtxt("../sk/psf_phase_y.txt")

# psf_coords = np.loadtxt("../sk/psf_amp_x.txt")
# psf_y = np.loadtxt("../sk/psf_amp_y.txt")

# %%
psf_coords = np.loadtxt("../sk/psf_amp_x.txt")
psf_y = np.loadtxt("../sk/psf_amp_y.txt")

foo = []
for y in psf_y.T:
    #foo.append(gmvpfit( psf_coords[:,:], y, plot=True,fitatol=0.005,verbose=True,maxdeg_list=[3,3,1]))
    foo.append(gmvrfit( psf_coords[:,:], y,fitatol=0.01,verbose=True,maxdeg_list=[2,2,1]))
    foo[-1].plot()
    show()
# Out:
# (gmvrfit)>> Now working deg = 1
# && The estimator has changed by -inf
# && Degree tempering will continue.
# && The current boundary is [('0', True), ('1', True), ('1', False)]
# && The current estimator value is 0.118660
#
# (gmvrfit)>> Now working deg = 2
# && The estimator has changed by -0.023203
# && Degree tempering will continue.
# && The current boundary is [('0', True), ('12', True), ('12', False), ('11', False)]
# && The current estimator value is 0.095458
#
# (gmvrfit)>> Now working deg = 3
# && The estimator has changed by -0.000804
# && Degree tempering has completed becuase the estimator has changed by |-0.000804| < 0.010000. The results of the last iteration will be kept.
# && The Final boundary is [('0', True), ('12', True), ('12', False), ('11', False)]
# && The Final estimator value is 0.095458
#
#
# ...
# # Degree Tempered Positive Greedy Solution:
# ...

# %%
psf_coords = np.loadtxt("../sk/psf_phase_x.txt")
psf_y = np.loadtxt("../sk/psf_phase_y.txt")

foo = []
for y in psf_y.T:
    #foo.append(gmvpfit( psf_coords[:,:], y, plot=True,fitatol=0.005,verbose=True,maxdeg_list=[3,3,1]))
    foo.append(gmvrfit( psf_coords[:,:], y,fitatol=0.01,verbose=True,maxdeg_list=[2,2,1]))
    foo[-1].plot()
    show()
# Out:
# (gmvrfit)>> Now working deg = 1
# && The estimator has changed by -inf
# && Degree tempering will continue.
# && The current boundary is [('1', True), ('0', True), ('2', True), ('0', False), ('1', False)]
# && The current estimator value is 0.347634
#
# (gmvrfit)>> Now working deg = 2
# && The estimator has changed by -0.139532
# && Degree tempering will continue.
# && The current boundary is [('12', True), ('0', True), ('2', True), ('11', True), ('00', False), ('12', False), ('11', False)]
# && The current estimator value is 0.208102
#
# (gmvrfit)>> Now working deg = 3
# && The estimator has changed by 0.008175
# && Degree tempering has completed becuase the estimator was made worse by using this max degree. The results of the last iteration will be kept.
# && The Final boundary is [('12', True), ('0', True), ('2', True), ('11', True), ('00', False), ('12', False), ('11', False)]
# && The Final estimator value is 0.208102
#
#
# ...
# # Degree Tempered Positive Greedy Solution:
# ...
