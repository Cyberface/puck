# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 16}) 

import h5py
import numpy as np

from scipy.interpolate import InterpolatedUnivariateSpline as IUS

# %%
import phenom
import numpy as np

# %%
import puck

# %%
# wf = puck.Waveform(filename='data/q1a04t120_dP0_T_96_552.h5')
wf = puck.Waveform(filename='data/q4a08t90dPm1D_T_96_384.h5')

# %%
wf.info
# Out:
# simname: q4a08t90dPm1D_T_96_384
# filename: data/q4a08t90dPm1D_T_96_384.h5
# eta: 0.16000039999600005
# X1: [-7.27303692e-04  7.99961251e-01 -5.49319079e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.977977
# final spin: 0.468547
# ringdown freq: 0.074205
# ringdown damp: 0.014009

# %%
wf.compute_fft(t12=[-1500, -1000], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.01, f_max=0.14)
# wf.compute_fft(t12=[-1000, -500], t34=[100, 101], plot=True, take_pos_f=True, f_min=0.01, f_max=0.3)
# Out:
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))

# %%
wf.plot_fd(xlim=[0.01,0.12])

# %%
wf.plot_td(xlim=[-600,100])
# wf.plot_td()

# %% [markdown]
# # loop over all

# %%
import glob
all_files = glob.glob('data/*.h5')

# %%
len(all_files)
# Out:
# 40

# %%
all_files
# Out:
# ['data/q4a08t90dPm1D_T_96_384.h5',
#  'data/q2a04t30dPm2_T_96_408.h5',
#  'data/q8a08t90dP0_T_96_384.h5',
#  'data/q4a04t90_T_96_360.h5',
#  'data/q2_a10_a28_ph0_th120.h5',
#  'data/q8a04t150dP9_T_96_360.h5',
#  'data/q4a08t60dPm3dRm250_T_96_384.h5',
#  'data/q2_a10_a28_ph0_th30.h5',
#  'data/q2a04t120_T_96_408.h5',
#  'data/q4a04t60dPm1.5D_T_96_360.h5',
#  'data/q2a04t150_T_96_408.h5',
#  'data/q4a08t30dPm5p5dRm47_T_96_360.h5',
#  'data/q1a08t30dPm25_T_96_408.h5',
#  'data/q2_a10_a28_ph0_th60.h5',
#  'data/q8a08t120dP2_r03_T_96_360.h5',
#  'data/q2a04t60dPm1_T_96_408.h5',
#  'data/q4a08t120dP1_T_96_360.h5',
#  'data/q1a08t150dP0_T_96_408.h5',
#  'data/q1a08t60dPm1.5_T_96_408.h5',
#  'data/q8a08t30dPm9.35_r0.5_T_96_360.h5',
#  'data/q8a04t90dP0_T_96_360.h5',
#  'data/q1a04t90_dP0_T_96_552.h5',
#  'data/q8a08t60Ditm45dr075_96_360.h5',
#  'data/q8a04t30dPm3_T_96_360.h5',
#  'data/q8a04t120dPp1_T_96_360.h5',
#  'data/q4a04t150_T_96_360.h5',
#  'data/q4a04t30_T_96_360.h5',
#  'data/q1a04t60_dPm1_T_96_552.h5',
#  'data/q2_a10_a28_ph0_th150.h5',
#  'data/q1a04t150_dP0_T_96_552.h5',
#  'data/q1a04t30_dPm2_T_96_552.h5',
#  'data/q1a08t120dP0_T_96_408.h5',
#  'data/q8a08t150dP2_T_120_480.h5',
#  'data/q1a08t90dPm1_T_96_408.h5',
#  'data/q4a08t150_T_96_360.h5',
#  'data/q2_a10_a28_ph0_th90.h5',
#  'data/q4a04t120dP0D_T_96_360.h5',
#  'data/q2a04t90dPm1_T_96_408.h5',
#  'data/q8a04t60D_dPm1.h5',
#  'data/q1a04t120_dP0_T_96_552.h5']

# %%
all_files[0]
# Out:
# 'data/q4a08t90dPm1D_T_96_384.h5'

# %%
wfs = []
for i, f in enumerate(all_files):
    print(f"working: {i}/{len(all_files)}")
#     if "q8a08t150dP2_T_96_360" in f:
#         continue
#     if "q8a04t60D_dPm1" in f:
#         continue
    wf = puck.Waveform(filename=f)
    print("info:")
    wf.info
    print("\n")
    
#     wf.compute_fft(t12=[-1400, -1000], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.025, f_max=0.14)
    wf.compute_fft(t12=[-1500, -800], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.018, f_max=0.12)
    
    wfs.append(wf)
# Out:
# working: 0/40
# info:
# simname: q4a08t90dPm1D_T_96_384
# filename: data/q4a08t90dPm1D_T_96_384.h5
# eta: 0.16000039999600005
# X1: [-7.27303692e-04  7.99961251e-01 -5.49319079e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.977977
# final spin: 0.468547
# ringdown freq: 0.074205
# ringdown damp: 0.014009
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 1/40
# info:
# simname: q2a04t30dPm2_T_96_408
# filename: data/q2a04t30dPm2_T_96_408.h5
# eta: 0.22222277777233335
# X1: [0.12702494 0.20023472 0.32212413]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.954422
# final spin: 0.720741
# ringdown freq: 0.090406
# ringdown damp: 0.013334
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 2/40
# info:
# simname: q8a08t90dP0_T_96_384
# filename: data/q8a08t90dP0_T_96_384.h5
# eta: 0.09876544444344446
# X1: [0.00713932 0.79993887 0.00489358]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.98938
# final spin: 0.310634
# ringdown freq: 0.067809
# ringdown damp: 0.0141
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 3/40
# info:
# simname: q4a04t90_T_96_360
# filename: data/q4a04t90_T_96_360.h5
# eta: 0.160000199999
# X1: [-1.36875477e-03  3.99991875e-01 -7.23300334e-05]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.97791
# final spin: 0.47145
# ringdown freq: 0.074329
# ringdown damp: 0.014004
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 4/40
# info:
# simname: q2_a10_a28_ph0_th120
# filename: data/q2_a10_a28_ph0_th120.h5
# eta: 0.22222311110000012
# X1: [-0.17521407  0.69148664 -0.36209136]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.966642
# final spin: 0.51029
# ringdown freq: 0.076875
# ringdown damp: 0.014074
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 5/40
# info:
# simname: q8a04t150dP9_T_96_360
# filename: data/q8a04t150dP9_T_96_360.h5
# eta: 0.09876538271585186
# X1: [ 0.13749907  0.19910167 -0.31851255]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.991079
# final spin: 0.07237
# ringdown freq: 0.061532
# ringdown damp: 0.014258
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 6/40
# info:
# simname: q4a08t60dPm3dRm250_T_96_384
# filename: data/q4a08t60dPm3dRm250_T_96_384.h5
# eta: 0.16000039999600005
# X1: [0.13490444 0.69525762 0.37200164]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.971768
# final spin: 0.666849
# ringdown freq: 0.084933
# ringdown damp: 0.013421
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 7/40
# info:
# simname: q2_a10_a28_ph0_th30
# filename: data/q2_a10_a28_ph0_th30.h5
# eta: 0.22222311110000012
# X1: [-0.05550302  0.40114802  0.68990043]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.942401
# final spin: 0.824729
# ringdown freq: 0.101833
# ringdown damp: 0.012453
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 8/40
# info:
# simname: q2a04t120_T_96_408
# filename: data/q2a04t120_T_96_408.h5
# eta: 0.22222277777233335
# X1: [ 0.15059256  0.34610192 -0.13239738]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.963432
# final spin: 0.582506
# ringdown freq: 0.080665
# ringdown damp: 0.013902
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 9/40
# info:
# simname: q4a04t60dPm1.5D_T_96_360
# filename: data/q4a04t60dPm1.5D_T_96_360.h5
# eta: 0.160000199999
# X1: [0.02692763 0.34702847 0.19708347]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.975101
# final spin: 0.576216
# ringdown freq: 0.079372
# ringdown damp: 0.013757
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 10/40
# info:
# simname: q2a04t150_T_96_408
# filename: data/q2a04t150_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-0.25890258  0.19961486 -0.23047212]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.964885
# final spin: 0.551813
# ringdown freq: 0.078973
# ringdown damp: 0.013982
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 11/40
# info:
# simname: q4a08t30dPm5p5dRm47_T_96_360
# filename: data/q4a08t30dPm5p5dRm47_T_96_360.h5
# eta: 0.16000039999600005
# X1: [0.41810205 0.40231025 0.55073154]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.967059
# final spin: 0.755626
# ringdown freq: 0.092133
# ringdown damp: 0.012889
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 12/40
# info:
# simname: q1a08t30dPm25_T_96_408
# filename: data/q1a08t30dPm25_T_96_408.h5
# eta: 0.25
# X1: [-0.18281502 -0.40033359  0.66803195]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.940355
# final spin: 0.785548
# ringdown freq: 0.097649
# ringdown damp: 0.012963
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 13/40
# info:
# simname: q2_a10_a28_ph0_th60
# filename: data/q2_a10_a28_ph0_th60.h5
# eta: 0.22222311110000012
# X1: [-0.26675028  0.69383782  0.29563047]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.955082
# final spin: 0.712922
# ringdown freq: 0.089731
# ringdown damp: 0.013379
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 14/40
# info:
# simname: q8a08t120dP2_r03_T_96_360
# filename: data/q8a08t120dP2_r03_T_96_360.h5
# eta: 0.09876544444344446
# X1: [-0.34656989  0.68919997  0.21182506]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.98779
# final spin: 0.462669
# ringdown freq: 0.073231
# ringdown damp: 0.013882
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 15/40
# info:
# simname: q2a04t60dPm1_T_96_408
# filename: data/q2a04t60dPm1_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-0.12855603  0.34671391  0.1525003 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.958315
# final spin: 0.670091
# ringdown freq: 0.086343
# ringdown damp: 0.013592
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 16/40
# info:
# simname: q4a08t120dP1_T_96_360
# filename: data/q4a08t120dP1_T_96_360.h5
# eta: 0.16000039999600005
# X1: [-0.2159821   0.69025306 -0.34186333]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.981335
# final spin: 0.287549
# ringdown freq: 0.067665
# ringdown damp: 0.014242
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 17/40
# info:
# simname: q1a08t150dP0_T_96_408
# filename: data/q1a08t150dP0_T_96_408.h5
# eta: 0.25
# X1: [-0.51296553 -0.39939402 -0.46615922]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.957178
# final spin: 0.61355
# ringdown freq: 0.082917
# ringdown damp: 0.013874
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 18/40
# info:
# simname: q1a08t60dPm1.5_T_96_408
# filename: data/q1a08t60dPm1.5_T_96_408.h5
# eta: 0.25
# X1: [-0.08390818 -0.69307905  0.39058114]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.945632
# final spin: 0.745271
# ringdown freq: 0.093299
# ringdown damp: 0.013269
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 19/40
# info:
# simname: q8a08t30dPm9.35_r0.5_T_96_360
# filename: data/q8a08t30dPm9.35_r0.5_T_96_360.h5
# eta: 0.09876544444344446
# X1: [0.03222868 0.40367765 0.68991503]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.980372
# final spin: 0.792449
# ringdown freq: 0.094354
# ringdown damp: 0.012361
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 20/40
# info:
# simname: q8a04t90dP0_T_96_360
# filename: data/q8a04t90dP0_T_96_360.h5
# eta: 0.09876538271585186
# X1: [ 0.00178953  0.39999165 -0.00115601]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.989419
# final spin: 0.306166
# ringdown freq: 0.06767
# ringdown damp: 0.014105
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 21/40
# info:
# simname: q1a04t90_dP0_T_96_552
# filename: data/q1a04t90_dP0_T_96_552.h5
# eta: 0.25
# X1: [-5.32667216e-05  3.99990400e-01 -2.81576042e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.951616
# final spin: 0.686374
# ringdown freq: 0.088083
# ringdown damp: 0.013596
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 22/40
# info:
# simname: q8a08t60Ditm45dr075_96_360
# filename: data/q8a08t60Ditm45dr075_96_360.h5
# eta: 0.09876620987653086
# X1: [0.15898056 0.69653853 0.35991855]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.986249
# final spin: 0.569392
# ringdown freq: 0.078128
# ringdown damp: 0.013624
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 23/40
# info:
# simname: q8a04t30dPm3_T_96_360
# filename: data/q8a04t30dPm3_T_96_360.h5
# eta: 0.09876538271585186
# X1: [0.33332279 0.20092416 0.09232214]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.988771
# final spin: 0.375105
# ringdown freq: 0.069932
# ringdown damp: 0.014024
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 24/40
# info:
# simname: q8a04t120dPp1_T_96_360
# filename: data/q8a04t120dPp1_T_96_360.h5
# eta: 0.09876538271585186
# X1: [-0.17037978  0.34549422 -0.10771393]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.990056
# final spin: 0.227452
# ringdown freq: 0.065373
# ringdown damp: 0.014174
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 25/40
# info:
# simname: q4a04t150_T_96_360
# filename: data/q4a04t150_T_96_360.h5
# eta: 0.160000199999
# X1: [-0.02705529  0.19936626 -0.34571287]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.981367
# final spin: 0.285477
# ringdown freq: 0.067602
# ringdown damp: 0.014244
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 26/40
# info:
# simname: q4a04t30_T_96_360
# filename: data/q4a04t30_T_96_360.h5
# eta: 0.160000199999
# X1: [-0.2981619   0.20061312  0.17564155]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.975448
# final spin: 0.564927
# ringdown freq: 0.078768
# ringdown damp: 0.01379
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 27/40
# info:
# simname: q1a04t60_dPm1_T_96_552
# filename: data/q1a04t60_dPm1_T_96_552.h5
# eta: 0.25
# X1: [-0.01989968  0.34642529  0.19896202]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.948747
# final spin: 0.716681
# ringdown freq: 0.090625
# ringdown damp: 0.013442
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 28/40
# info:
# simname: q2_a10_a28_ph0_th150
# filename: data/q2_a10_a28_ph0_th150.h5
# eta: 0.22222311110000012
# X1: [ 0.08533201  0.3983536  -0.68847397]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.970244
# final spin: 0.405969
# ringdown freq: 0.072367
# ringdown damp: 0.014242
# working: 29/40
# info:
# simname: q1a04t150_dP0_T_96_552
# filename: data/q1a04t150_dP0_T_96_552.h5
# eta: 0.25
# X1: [-0.02297821  0.1999164  -0.3456845 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.955872
# final spin: 0.632621
# ringdown freq: 0.084162
# ringdown damp: 0.013811
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 30/40
# info:
# simname: q1a04t30_dPm2_T_96_552
# filename: data/q1a04t30_dPm2_T_96_552.h5
# eta: 0.25
# X1: [-0.01213047  0.200022    0.34617369]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.946388
# final spin: 0.738698
# ringdown freq: 0.092657
# ringdown damp: 0.013311
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 31/40
# info:
# simname: q1a08t120dP0_T_96_408
# filename: data/q1a08t120dP0_T_96_408.h5
# eta: 0.25
# X1: [ 0.02445732 -0.69238307 -0.3999528 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.95647
# final spin: 0.624049
# ringdown freq: 0.083594
# ringdown damp: 0.01384
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 32/40
# info:
# simname: q8a08t150dP2_T_120_480
# filename: data/q8a08t150dP2_T_120_480.h5
# eta: 0.09876544444344446
# X1: [0.64241193 0.39653206 0.26466267]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.987288
# final spin: 0.501033
# ringdown freq: 0.074863
# ringdown damp: 0.013803
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 33/40
# info:
# simname: q1a08t90dPm1_T_96_408
# filename: data/q1a08t90dPm1_T_96_408.h5
# eta: 0.25
# X1: [ 8.95531761e-04 -7.99971201e-01 -4.11881172e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.951618
# final spin: 0.686354
# ringdown freq: 0.088082
# ringdown damp: 0.013596
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 34/40
# info:
# simname: q4a08t150_T_96_360
# filename: data/q4a08t150_T_96_360.h5
# eta: 0.16000227999963998
# X1: [ 0.494267    0.3974145  -0.48757965]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.982432
# final spin: 0.209253
# ringdown freq: 0.065392
# ringdown damp: 0.014299
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 35/40
# info:
# simname: q2_a10_a28_ph0_th90
# filename: data/q2_a10_a28_ph0_th90.h5
# eta: 0.22222311110000012
# X1: [ 5.14092605e-04  7.99971851e-01 -3.23455443e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.961296
# final spin: 0.622541
# ringdown freq: 0.083085
# ringdown damp: 0.013777
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 36/40
# info:
# simname: q4a04t120dP0D_T_96_360
# filename: data/q4a04t120dP0D_T_96_360.h5
# eta: 0.160000199999
# X1: [ 0.09332774  0.34579099 -0.17808684]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.979871
# final spin: 0.375761
# ringdown freq: 0.07059
# ringdown damp: 0.01415
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 37/40
# info:
# simname: q2a04t90dPm1_T_96_408
# filename: data/q2a04t90dPm1_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-8.23707099e-05  3.99990650e-01 -8.11305335e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.961253
# final spin: 0.623287
# ringdown freq: 0.083133
# ringdown damp: 0.013775
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 38/40
# info:
# simname: q8a04t60D_dPm1
# filename: data/q8a04t60D_dPm1.h5
# eta: 0.09876538271585186
# X1: [0.16242918 0.3473319  0.1139076 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.988608
# final spin: 0.390983
# ringdown freq: 0.070492
# ringdown damp: 0.014002
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 39/40
# info:
# simname: q1a04t120_dP0_T_96_552
# filename: data/q1a04t120_dP0_T_96_552.h5
# eta: 0.25
# X1: [ 0.04721567  0.34626489 -0.19458573]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.95411
# final spin: 0.656311
# ringdown freq: 0.085809
# ringdown damp: 0.013724
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:26: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,5))
axes[0].plot(wfs[0].fd['freqs'], wfs[0].fd['psi4']['dphase'])
axes[1].plot(wfs[0].fd['freqs'], wfs[0].fd['strain']['dphase'])
# for ax in axes:
#     ax.set_xlim(*xlim)

axes[0].axvline(wfs[0].fring)
axes[1].axvline(wfs[1].fring)

# %%
# for wf in wfs:
#     wf.compute_fft(t12=[-1500, -800], t34=[100, 150], plot=False, take_pos_f=True, f_min=0.018, f_max=0.12)

# %%
plt.figure()
for wf in wfs:
    plt.plot(wf.fd['freqs'], wf.fd['psi4']['dphase']-wf.fd['psi4']['dphase'][0])

# %% [markdown]
# # fit

# %%
from lmfit import Model, Parameter, report_fit

# %%
def dphimrd_func(f, a1, a2, a3, a4, a5, a6, fdamp, frd):
    """
    added a6 to modify fdamp
    """
    part1 = a1 + a2*f**(-2) + a3*f**(-1/4.)
    part2 = a4 * (a6*fdamp) / ((a6*fdamp)**2 + (f-a5*frd)**2)
    return part1 + part2

# %%
def fit(wf):
    model = Model(dphimrd_func, independent_vars=['f'])
    x = wf.fd['freqs']
    y = wf.fd['psi4']['dphase']-wf.fd['psi4']['dphase'][0]

    f1 = wf.fring*0.45
    f2 = wf.fring*1.5
    
    mask = (x>f1) & (x<f2)
    x = x[mask]
    y = y[mask]
    y = y
    
#     plt.figure()
#     plt.scatter(x, y)
#     plt.show()
#     plt.close()
    
    params = model.make_params()
    
    params['fdamp'].value = wf.fdamp
    params['fdamp'].min = wf.fdamp/5
    params['fdamp'].max = wf.fdamp*5
    params['fdamp'].vary=False


    params['frd'].value = wf.fring
#     params['frd'].min = wf.fring-0.1
#     params['frd'].max = wf.fring+0.2
    params['frd'].vary=False

    params['a1'].value = 400
    params['a1'].min = -100000
    params['a1'].max = 100000
    # params['a1'].vary=False

    params['a2'].value = 1
    params['a2'].min = -1000
    params['a2'].max = 1000
    # params['a2'].vary=False

    params['a3'].value = 100
    params['a3'].min = 0
    params['a3'].max = 100000
    # params['a3'].vary=False

    params['a4'].value = 100
    params['a4'].min = -1000
    params['a4'].max = 1000
    # params['a4'].vary=False

    params['a5'].value = 1
    params['a5'].min = -6
    params['a5'].max = 6
    # params['a5'].vary=False
    
    params['a6'].value = 1
    params['a6'].min = -10
    params['a6'].max = 10
    params['a6'].vary=False

    result = model.fit(y, params, f=x)
    
    report_fit(result.params)
    
    result.plot()
    plt.axvline(wf.fring, c='k', ls='--', label='fRD prediction')
    plt.show()
    plt.close()
    
    return result

# %%
0.01362*1.2
# Out:
# 0.016344

# %%
[wf.simname for wf in wfs].index('q8a08t60Ditm45dr075_96_360')
# Out:
# 22

# %%
[wf.simname for wf in wfs].index('q8a08t150dP2_T_120_480')
# Out:
# 32

# %%
0.013624*0.930
# Out:
# 0.01267032

# %%
fit(wfs[22])
# Out:
# [[Variables]]
#     a1:    -2006.68191 +/- 7.14704438 (0.36%) (init = 400)
#     a2:     0.31397363 +/- 0.00327705 (1.04%) (init = 1)
#     a3:     94.4216295 +/- 4.01608965 (4.25%) (init = 100)
#     a4:    -1.33596857 +/- 0.00901792 (0.68%) (init = 100)
#     a5:     1.20696693 +/- 8.2616e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013624 (fixed)
#     frd:    0.078128 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.951
#     C(a1, a2) =  0.931
#     C(a1, a5) =  0.604
#     C(a3, a5) = -0.603
#     C(a2, a5) =  0.543
#     C(a1, a4) = -0.522
#     C(a3, a4) =  0.473
#     C(a4, a5) = -0.307
#     C(a2, a4) = -0.260
# <h2> Model</h2> Model(dphimrd_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>110</td><td></td></tr><tr><td># data points</td><td>2207</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 81688.9729</td><td></td></tr><tr><td>reduced chi-square</td><td> 37.0976262</td><td></td></tr><tr><td>Akaike info crit.</td><td> 7980.10576</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 8008.60271</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a1 </td><td> -2006.68191 </td><td>  7.14704438 </td><td> (0.36%) </td><td> 400 </td><td> -100000.000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a2 </td><td>  0.31397363 </td><td>  0.00327705 </td><td> (1.04%) </td><td> 1 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a3 </td><td>  94.4216295 </td><td>  4.01608965 </td><td> (4.25%) </td><td> 100 </td><td>  0.00000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a4 </td><td> -1.33596857 </td><td>  0.00901792 </td><td> (0.68%) </td><td> 100 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a5 </td><td>  1.20696693 </td><td>  8.2616e-04 </td><td> (0.07%) </td><td> 1 </td><td> -6.00000000 </td><td>  6.00000000 </td><td> True </td></tr><tr><td> a6 </td><td>  1.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1 </td><td> -10.0000000 </td><td>  10.0000000 </td><td> False </td></tr><tr><td> fdamp </td><td>  0.01362400 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.013624 </td><td>  0.00272480 </td><td>  0.06812000 </td><td> False </td></tr><tr><td> frd </td><td>  0.07812800 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.078128 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a1</td><td>a3</td><td>-0.9980</td></tr><tr><td>a2</td><td>a3</td><td>-0.9506</td></tr><tr><td>a1</td><td>a2</td><td>0.9310</td></tr><tr><td>a1</td><td>a5</td><td>0.6044</td></tr><tr><td>a3</td><td>a5</td><td>-0.6030</td></tr><tr><td>a2</td><td>a5</td><td>0.5427</td></tr><tr><td>a1</td><td>a4</td><td>-0.5217</td></tr><tr><td>a3</td><td>a4</td><td>0.4732</td></tr><tr><td>a4</td><td>a5</td><td>-0.3069</td></tr><tr><td>a2</td><td>a4</td><td>-0.2598</td></tr></table>

# %%
fits = []
for wf in wfs:
    print(f"working: {wf.simname} \n")
    fits.append(fit(wf))
# Out:
# working: q4a08t90dPm1D_T_96_384
#
# [[Variables]]
#     a1:    -964.964073 +/- 3.87000618 (0.40%) (init = 400)
#     a2:     0.25536553 +/- 0.00177870 (0.70%) (init = 1)
#     a3:     1.2546e-09 +/- 0.07305507 (5823199529.43%) (init = 100)
#     a4:    -1.19517795 +/- 0.00471877 (0.39%) (init = 100)
#     a5:     1.12222616 +/- 6.0397e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014009 (fixed)
#     frd:    0.074205 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.956
#     C(a1, a2) =  0.936
#     C(a1, a5) =  0.625
#     C(a3, a5) =  0.616
#     C(a2, a5) =  0.526
#     C(a2, a4) =  0.159
#     C(a4, a5) = -0.121
# working: q2a04t30dPm2_T_96_408
#
# [[Variables]]
#     a1:    -1016.81710 +/- 2.03396957 (0.20%) (init = 400)
#     a2:     0.30408289 +/- 0.00127751 (0.42%) (init = 1)
#     a3:     3.58014651 +/- 1.20063744 (33.54%) (init = 100)
#     a4:    -1.20223056 +/- 0.00195183 (0.16%) (init = 100)
#     a5:     1.01326665 +/- 1.9815e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013334 (fixed)
#     frd:    0.090406 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.965
#     C(a1, a2) =  0.949
#     C(a1, a5) =  0.596
#     C(a3, a5) = -0.587
#     C(a2, a5) =  0.506
#     C(a2, a4) =  0.207
# working: q8a08t90dP0_T_96_384
#
# [[Variables]]
#     a1:    -1119.28377 +/- 9.83596697 (0.88%) (init = 400)
#     a2:     0.24069155 +/- 0.00345858 (1.44%) (init = 1)
#     a3:     6.7613e-09 +/- 2.16765084 (32059873587.44%) (init = 100)
#     a4:    -1.01285085 +/- 0.01248549 (1.23%) (init = 100)
#     a5:     1.17259344 +/- 0.00183763 (0.16%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.0141 (fixed)
#     frd:    0.067809 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.950
#     C(a1, a2) =  0.929
#     C(a1, a5) =  0.683
#     C(a3, a5) = -0.678
#     C(a2, a5) =  0.597
#     C(a1, a4) = -0.408
#     C(a3, a4) =  0.350
#     C(a4, a5) = -0.293
#     C(a2, a4) = -0.123
# working: q4a04t90_T_96_360
#
# [[Variables]]
#     a1:    -904.608710 +/- 0.99990732 (0.11%) (init = 400)
#     a2:     0.22555024 +/- 4.9065e-04 (0.22%) (init = 1)
#     a3:     12.4253882 +/- 0.58357550 (4.70%) (init = 100)
#     a4:    -1.09416816 +/- 0.00117046 (0.11%) (init = 100)
#     a5:     1.02417588 +/- 1.5871e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014004 (fixed)
#     frd:    0.074329 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.972
#     C(a1, a2) =  0.960
#     C(a1, a5) =  0.576
#     C(a3, a5) = -0.563
#     C(a2, a4) =  0.560
#     C(a3, a4) = -0.475
#     C(a2, a5) =  0.474
#     C(a1, a4) =  0.433
#     C(a4, a5) =  0.148
# working: q2_a10_a28_ph0_th120
#
# [[Variables]]
#     a1:    -672.894852 +/- 2.60648968 (0.39%) (init = 400)
#     a2:     0.20163898 +/- 0.00136831 (0.68%) (init = 1)
#     a3:     5.41565974 +/- 1.53206496 (28.29%) (init = 100)
#     a4:    -1.22513665 +/- 0.00307847 (0.25%) (init = 100)
#     a5:     1.02957804 +/- 3.6832e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014074 (fixed)
#     frd:    0.076875 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.971
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.567
#     C(a3, a5) = -0.554
#     C(a2, a4) =  0.536
#     C(a2, a5) =  0.466
#     C(a3, a4) = -0.446
#     C(a1, a4) =  0.403
#     C(a4, a5) =  0.130
# working: q8a04t150dP9_T_96_360
#
# [[Variables]]
#     a1:    -662.219140 +/- 0.68228671 (0.10%) (init = 400)
#     a2:     0.16655135 +/- 2.2613e-04 (0.14%) (init = 1)
#     a3:     5.1086e-07 +/- 19.1681746 (3752112232.33%) (init = 100)
#     a4:    -1.05245875 +/- 8.0423e-04 (0.08%) (init = 100)
#     a5:     1.00132801 +/- 1.2529e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014258 (fixed)
#     frd:    0.061532 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.977
#     C(a1, a2) =  0.966
#     C(a2, a4) =  0.672
#     C(a1, a5) =  0.652
#     C(a3, a5) =  0.636
#     C(a3, a4) =  0.606
#     C(a1, a4) =  0.569
#     C(a2, a5) =  0.539
#     C(a4, a5) =  0.252
# working: q4a08t60dPm3dRm250_T_96_384
#
# [[Variables]]
#     a1:    -1463.68222 +/- 3.65028560 (0.25%) (init = 400)
#     a2:     0.31482403 +/- 0.00199230 (0.63%) (init = 1)
#     a3:     71.8086937 +/- 2.10288018 (2.93%) (init = 100)
#     a4:    -1.32894529 +/- 0.00406786 (0.31%) (init = 100)
#     a5:     1.11688267 +/- 3.7264e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013421 (fixed)
#     frd:    0.084933 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.955
#     C(a1, a2) =  0.936
#     C(a1, a5) =  0.602
#     C(a3, a5) = -0.597
#     C(a2, a5) =  0.526
#     C(a1, a4) = -0.343
#     C(a3, a4) =  0.290
#     C(a4, a5) = -0.233
# working: q2_a10_a28_ph0_th30
#
# [[Variables]]
#     a1:    -1485.00469 +/- 1.40058972 (0.09%) (init = 400)
#     a2:     0.31078488 +/- 8.3227e-04 (0.27%) (init = 1)
#     a3:     121.228531 +/- 0.80813975 (0.67%) (init = 100)
#     a4:    -1.11064130 +/- 0.00115272 (0.10%) (init = 100)
#     a5:     1.02814161 +/- 6.8427e-05 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012453 (fixed)
#     frd:    0.101833 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.972
#     C(a1, a2) =  0.962
#     C(a1, a4) = -0.748
#     C(a3, a4) =  0.724
#     C(a3, a5) = -0.615
#     C(a1, a5) =  0.613
#     C(a2, a5) =  0.595
#     C(a2, a4) = -0.580
#     C(a4, a5) = -0.420
# working: q2a04t120_T_96_408
#
# [[Variables]]
#     a1:    -717.455241 +/- 2.79851078 (0.39%) (init = 400)
#     a2:     0.21336581 +/- 0.00161675 (0.76%) (init = 1)
#     a3:     5.6821e-08 +/- 1.65831708 (2918482298.45%) (init = 100)
#     a4:    -1.18718626 +/- 0.00322586 (0.27%) (init = 100)
#     a5:     0.99298895 +/- 3.6228e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013902 (fixed)
#     frd:    0.080665 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.965
#     C(a2, a4) =  0.617
#     C(a3, a4) = -0.557
#     C(a1, a5) =  0.526
#     C(a1, a4) =  0.523
#     C(a3, a5) = -0.514
#     C(a2, a5) =  0.431
#     C(a4, a5) =  0.185
# working: q4a04t60dPm1.5D_T_96_360
#
# [[Variables]]
#     a1:    -1062.96307 +/- 1.42465100 (0.13%) (init = 400)
#     a2:     0.27265168 +/- 8.0052e-04 (0.29%) (init = 1)
#     a3:     1.8874e-08 +/- 0.10564133 (559724983.80%) (init = 100)
#     a4:    -1.17069336 +/- 0.00165390 (0.14%) (init = 100)
#     a5:     1.02651414 +/- 1.9857e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013757 (fixed)
#     frd:    0.079372 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.971
#     C(a1, a2) =  0.959
#     C(a1, a5) =  0.541
#     C(a2, a4) =  0.535
#     C(a3, a5) =  0.529
#     C(a3, a4) =  0.450
#     C(a2, a5) =  0.444
#     C(a1, a4) =  0.409
#     C(a4, a5) =  0.128
# working: q2a04t150_T_96_408
#
# [[Variables]]
#     a1:    -663.004891 +/- 2.72183841 (0.41%) (init = 400)
#     a2:     0.19986337 +/- 0.00151399 (0.76%) (init = 1)
#     a3:     2.0051e-08 +/- 0.29462243 (1469392555.06%) (init = 100)
#     a4:    -1.13756004 +/- 0.00318813 (0.28%) (init = 100)
#     a5:     0.97810763 +/- 3.6634e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013982 (fixed)
#     frd:    0.078973 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.999
#     C(a2, a3) =  0.978
#     C(a1, a2) =  0.969
#     C(a2, a4) =  0.670
#     C(a3, a4) =  0.626
#     C(a1, a4) =  0.596
#     C(a1, a5) =  0.518
#     C(a3, a5) =  0.506
#     C(a2, a5) =  0.423
#     C(a4, a5) =  0.223
# working: q4a08t30dPm5p5dRm47_T_96_360
#
# [[Variables]]
#     a1:    -1833.92461 +/- 4.71752271 (0.26%) (init = 400)
#     a2:     0.39442211 +/- 0.00248734 (0.63%) (init = 1)
#     a3:     80.5050686 +/- 2.68457199 (3.33%) (init = 100)
#     a4:    -1.39006545 +/- 0.00473277 (0.34%) (init = 100)
#     a5:     1.11987438 +/- 2.6596e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012889 (fixed)
#     frd:    0.092133 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.954
#     C(a1, a4) = -0.736
#     C(a3, a4) =  0.708
#     C(a3, a5) = -0.592
#     C(a1, a5) =  0.590
#     C(a2, a5) =  0.569
#     C(a2, a4) = -0.550
#     C(a4, a5) = -0.394
# working: q1a08t30dPm25_T_96_408
#
# [[Variables]]
#     a1:    -1146.92196 +/- 2.20033219 (0.19%) (init = 400)
#     a2:     0.29943566 +/- 0.00140108 (0.47%) (init = 1)
#     a3:     59.7852243 +/- 1.28768428 (2.15%) (init = 100)
#     a4:    -1.14403801 +/- 0.00188829 (0.17%) (init = 100)
#     a5:     1.00193081 +/- 1.6309e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012963 (fixed)
#     frd:    0.097649 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.635
#     C(a3, a5) = -0.630
#     C(a2, a5) =  0.565
#     C(a1, a4) = -0.371
#     C(a3, a4) =  0.325
#     C(a4, a5) = -0.271
#     C(a2, a4) = -0.131
# working: q2_a10_a28_ph0_th60
#
# [[Variables]]
#     a1:    -1196.86279 +/- 3.23439507 (0.27%) (init = 400)
#     a2:     0.26506920 +/- 0.00183002 (0.69%) (init = 1)
#     a3:     75.2808537 +/- 1.86542902 (2.48%) (init = 100)
#     a4:    -1.32473592 +/- 0.00333886 (0.25%) (init = 100)
#     a5:     1.08335076 +/- 2.7359e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013379 (fixed)
#     frd:    0.089731 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.958
#     C(a1, a2) =  0.941
#     C(a1, a5) =  0.622
#     C(a3, a5) = -0.618
#     C(a2, a5) =  0.555
#     C(a1, a4) = -0.439
#     C(a3, a4) =  0.392
#     C(a4, a5) = -0.288
#     C(a2, a4) = -0.188
# working: q8a08t120dP2_r03_T_96_360
#
# [[Variables]]
#     a1:    -648.770152 +/- 14.1281030 (2.18%) (init = 400)
#     a2:     0.13626228 +/- 0.00662076 (4.86%) (init = 1)
#     a3:     5.7722e-06 +/- 8.30340357 (143850534.88%) (init = 100)
#     a4:    -1.12261741 +/- 0.01656895 (1.48%) (init = 100)
#     a5:     0.92187275 +/- 0.00171556 (0.19%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013882 (fixed)
#     frd:    0.073231 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.983
#     C(a1, a2) =  0.978
#     C(a2, a4) =  0.789
#     C(a3, a4) = -0.779
#     C(a1, a4) =  0.760
#     C(a1, a5) =  0.490
#     C(a3, a5) = -0.478
#     C(a2, a5) =  0.395
#     C(a4, a5) =  0.309
# working: q2a04t60dPm1_T_96_408
#
# [[Variables]]
#     a1:    -951.322231 +/- 1.87540584 (0.20%) (init = 400)
#     a2:     0.27059089 +/- 0.00114180 (0.42%) (init = 1)
#     a3:     12.6919333 +/- 1.10925651 (8.74%) (init = 100)
#     a4:    -1.19628990 +/- 0.00194558 (0.16%) (init = 100)
#     a5:     1.02336485 +/- 2.1418e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013592 (fixed)
#     frd:    0.086343 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.952
#     C(a1, a5) =  0.578
#     C(a3, a5) = -0.568
#     C(a2, a5) =  0.484
#     C(a2, a4) =  0.336
#     C(a3, a4) = -0.196
#     C(a1, a4) =  0.147
# working: q4a08t120dP1_T_96_360
#
# [[Variables]]
#     a1:    -654.899254 +/- 3.90949252 (0.60%) (init = 400)
#     a2:     0.16592992 +/- 0.00154907 (0.93%) (init = 1)
#     a3:     4.5519e-10 +/- 2.41534087 (530620890176.11%) (init = 100)
#     a4:    -1.26238497 +/- 0.00464962 (0.37%) (init = 100)
#     a5:     1.06613851 +/- 6.1887e-04 (0.06%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014242 (fixed)
#     frd:    0.067665 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.950
#     C(a1, a5) =  0.649
#     C(a3, a5) = -0.636
#     C(a2, a5) =  0.537
#     C(a2, a4) =  0.422
#     C(a3, a4) = -0.286
#     C(a1, a4) =  0.231
# working: q1a08t150dP0_T_96_408
#
# [[Variables]]
#     a1:    -619.183658 +/- 8.84772288 (1.43%) (init = 400)
#     a2:     0.18609652 +/- 0.00528137 (2.84%) (init = 1)
#     a3:     1.1774e-08 +/- 0.98373865 (8355238149.59%) (init = 100)
#     a4:    -1.28485419 +/- 0.00973299 (0.76%) (init = 100)
#     a5:     0.97897858 +/- 9.8175e-04 (0.10%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013874 (fixed)
#     frd:    0.082917 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.976
#     C(a1, a2) =  0.966
#     C(a2, a4) =  0.610
#     C(a3, a4) = -0.547
#     C(a1, a5) =  0.532
#     C(a3, a5) = -0.520
#     C(a1, a4) =  0.513
#     C(a2, a5) =  0.438
#     C(a4, a5) =  0.179
# working: q1a08t60dPm1.5_T_96_408
#
# [[Variables]]
#     a1:    -962.762067 +/- 1.76686659 (0.18%) (init = 400)
#     a2:     0.31536500 +/- 0.00111950 (0.35%) (init = 1)
#     a3:     2.76395462 +/- 1.03927910 (37.60%) (init = 100)
#     a4:    -1.16420953 +/- 0.00162779 (0.14%) (init = 100)
#     a5:     1.00971094 +/- 1.5958e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013269 (fixed)
#     frd:    0.093299 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.616
#     C(a3, a5) = -0.608
#     C(a2, a5) =  0.531
#     C(a4, a5) = -0.164
#     C(a1, a4) = -0.157
#     C(a3, a4) =  0.107
# working: q8a08t30dPm9.35_r0.5_T_96_360
#
# [[Variables]]
#     a1:    -2778.07441 +/- 3.89993274 (0.14%) (init = 400)
#     a2:     0.45704841 +/- 0.00223567 (0.49%) (init = 1)
#     a3:     133.808151 +/- 2.24562974 (1.68%) (init = 100)
#     a4:    -1.23071764 +/- 0.00353025 (0.29%) (init = 100)
#     a5:     1.07030041 +/- 2.4612e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012361 (fixed)
#     frd:    0.094354 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.949
#     C(a1, a4) = -0.603
#     C(a1, a5) =  0.603
#     C(a3, a5) = -0.602
#     C(a3, a4) =  0.567
#     C(a2, a5) =  0.560
#     C(a2, a4) = -0.385
#     C(a4, a5) = -0.350
# working: q8a04t90dP0_T_96_360
#
# [[Variables]]
#     a1:    -1013.69862 +/- 2.69975457 (0.27%) (init = 400)
#     a2:     0.22255303 +/- 0.00108128 (0.49%) (init = 1)
#     a3:     1.1985e-07 +/- 1.52509069 (1272455717.26%) (init = 100)
#     a4:    -1.20968099 +/- 0.00316707 (0.26%) (init = 100)
#     a5:     1.04632307 +/- 4.2986e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014105 (fixed)
#     frd:    0.06767 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.969
#     C(a1, a2) =  0.955
#     C(a1, a5) =  0.634
#     C(a3, a5) = -0.620
#     C(a2, a5) =  0.523
#     C(a2, a4) =  0.500
#     C(a3, a4) = -0.388
#     C(a1, a4) =  0.338
#     C(a4, a5) =  0.103
# working: q1a04t90_dP0_T_96_552
#
# [[Variables]]
#     a1:    -796.629122 +/- 3.09171647 (0.39%) (init = 400)
#     a2:     0.25397530 +/- 0.00193339 (0.76%) (init = 1)
#     a3:     2.0268e-07 +/- 1.84256966 (909092466.73%) (init = 100)
#     a4:    -1.20295737 +/- 0.00309226 (0.26%) (init = 100)
#     a5:     1.00273289 +/- 3.3022e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013596 (fixed)
#     frd:    0.088083 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.968
#     C(a1, a2) =  0.954
#     C(a1, a5) =  0.580
#     C(a3, a5) = -0.569
#     C(a2, a5) =  0.485
#     C(a2, a4) =  0.365
#     C(a3, a4) = -0.232
#     C(a1, a4) =  0.185
# working: q8a08t60Ditm45dr075_96_360
#
# [[Variables]]
#     a1:    -2006.68191 +/- 7.14704438 (0.36%) (init = 400)
#     a2:     0.31397363 +/- 0.00327705 (1.04%) (init = 1)
#     a3:     94.4216295 +/- 4.01608965 (4.25%) (init = 100)
#     a4:    -1.33596857 +/- 0.00901792 (0.68%) (init = 100)
#     a5:     1.20696693 +/- 8.2616e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013624 (fixed)
#     frd:    0.078128 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.951
#     C(a1, a2) =  0.931
#     C(a1, a5) =  0.604
#     C(a3, a5) = -0.603
#     C(a2, a5) =  0.543
#     C(a1, a4) = -0.522
#     C(a3, a4) =  0.473
#     C(a4, a5) = -0.307
#     C(a2, a4) = -0.260
# working: q8a04t30dPm3_T_96_360
#
# [[Variables]]
#     a1:    -1600.26855 +/- 1.61846856 (0.10%) (init = 400)
#     a2:     0.33293835 +/- 6.6090e-04 (0.20%) (init = 1)
#     a3:     2.5313e-09 +/- 0.88327957 (34894189064.21%) (init = 100)
#     a4:    -1.07184160 +/- 0.00195625 (0.18%) (init = 100)
#     a5:     1.11466420 +/- 2.9361e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014024 (fixed)
#     frd:    0.069932 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.957
#     C(a1, a2) =  0.937
#     C(a1, a5) =  0.650
#     C(a3, a5) = -0.639
#     C(a2, a5) =  0.545
#     C(a2, a4) =  0.194
#     C(a4, a5) = -0.108
# working: q8a04t120dPp1_T_96_360
#
# [[Variables]]
#     a1:    -779.586156 +/- 2.62171585 (0.34%) (init = 400)
#     a2:     0.18426586 +/- 9.8662e-04 (0.54%) (init = 1)
#     a3:     9.7145e-10 +/- 1.40583670 (144716014695.67%) (init = 100)
#     a4:    -1.15429599 +/- 0.00307357 (0.27%) (init = 100)
#     a5:     1.00499715 +/- 4.2044e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014174 (fixed)
#     frd:    0.065373 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.976
#     C(a1, a2) =  0.965
#     C(a2, a4) =  0.647
#     C(a1, a5) =  0.626
#     C(a3, a5) = -0.611
#     C(a3, a4) = -0.579
#     C(a1, a4) =  0.540
#     C(a2, a5) =  0.516
#     C(a4, a5) =  0.225
# working: q4a04t150_T_96_360
#
# [[Variables]]
#     a1:    -652.316472 +/- 0.64050080 (0.10%) (init = 400)
#     a2:     0.17858584 +/- 2.5846e-04 (0.14%) (init = 1)
#     a3:     0.62955783 +/- 0.36645805 (58.21%) (init = 100)
#     a4:    -1.09955148 +/- 7.5477e-04 (0.07%) (init = 100)
#     a5:     1.00821653 +/- 1.0697e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014244 (fixed)
#     frd:    0.067602 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.964
#     C(a2, a4) =  0.632
#     C(a1, a5) =  0.616
#     C(a3, a5) = -0.601
#     C(a3, a4) = -0.561
#     C(a1, a4) =  0.522
#     C(a2, a5) =  0.507
#     C(a4, a5) =  0.210
# working: q4a04t30_T_96_360
#
# [[Variables]]
#     a1:    -1223.60171 +/- 0.75417712 (0.06%) (init = 400)
#     a2:     0.30048416 +/- 4.1044e-04 (0.14%) (init = 1)
#     a3:     10.4782971 +/- 0.44212167 (4.22%) (init = 100)
#     a4:    -1.16374660 +/- 8.8894e-04 (0.08%) (init = 100)
#     a5:     1.07164950 +/- 1.1226e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01379 (fixed)
#     frd:    0.078768 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.964
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.569
#     C(a3, a5) = -0.557
#     C(a2, a5) =  0.470
#     C(a2, a4) =  0.380
#     C(a3, a4) = -0.248
#     C(a1, a4) =  0.197
# working: q1a04t60_dPm1_T_96_552
#
# [[Variables]]
#     a1:    -868.832186 +/- 2.54296476 (0.29%) (init = 400)
#     a2:     0.28114989 +/- 0.00161681 (0.58%) (init = 1)
#     a3:     1.2006e-06 +/- 0.46529171 (38754549.83%) (init = 100)
#     a4:    -1.18337125 +/- 0.00242788 (0.21%) (init = 100)
#     a5:     1.00134992 +/- 2.5252e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013442 (fixed)
#     frd:    0.090625 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.967
#     C(a1, a2) =  0.952
#     C(a1, a5) =  0.595
#     C(a3, a5) =  0.585
#     C(a2, a5) =  0.503
#     C(a2, a4) =  0.264
#     C(a3, a4) =  0.110
# working: q2_a10_a28_ph0_th150
#
# [[Variables]]
#     a1:    -593.674104 +/- 4.13460847 (0.70%) (init = 400)
#     a2:     0.15923806 +/- 0.00192323 (1.21%) (init = 1)
#     a3:     20.0992109 +/- 2.40599379 (11.97%) (init = 100)
#     a4:    -1.09262790 +/- 0.00489273 (0.45%) (init = 100)
#     a5:     1.00417483 +/- 6.6083e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014242 (fixed)
#     frd:    0.072367 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.965
#     C(a2, a4) =  0.629
#     C(a1, a5) =  0.583
#     C(a3, a5) = -0.569
#     C(a3, a4) = -0.563
#     C(a1, a4) =  0.526
#     C(a2, a5) =  0.479
#     C(a4, a5) =  0.203
# working: q1a04t150_dP0_T_96_552
#
# [[Variables]]
#     a1:    -696.095256 +/- 4.80756909 (0.69%) (init = 400)
#     a2:     0.21401569 +/- 0.00290072 (1.36%) (init = 1)
#     a3:     4.7473e-08 +/- 2.35632313 (4963487348.13%) (init = 100)
#     a4:    -1.25147162 +/- 0.00518582 (0.41%) (init = 100)
#     a5:     1.00132283 +/- 5.5363e-04 (0.06%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013811 (fixed)
#     frd:    0.084162 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.972
#     C(a1, a2) =  0.960
#     C(a1, a5) =  0.555
#     C(a3, a5) =  0.543
#     C(a2, a4) =  0.505
#     C(a2, a5) =  0.459
#     C(a3, a4) =  0.410
#     C(a1, a4) =  0.368
#     C(a4, a5) =  0.105
# working: q1a04t30_dPm2_T_96_552
#
# [[Variables]]
#     a1:    -948.186965 +/- 2.89492356 (0.31%) (init = 400)
#     a2:     0.28096109 +/- 0.00186105 (0.66%) (init = 1)
#     a3:     18.6628346 +/- 1.71182693 (9.17%) (init = 100)
#     a4:    -1.17743820 +/- 0.00266623 (0.23%) (init = 100)
#     a5:     0.99810236 +/- 2.6716e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013311 (fixed)
#     frd:    0.092657 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.965
#     C(a1, a2) =  0.950
#     C(a1, a5) =  0.605
#     C(a3, a5) = -0.596
#     C(a2, a5) =  0.516
#     C(a2, a4) =  0.185
#     C(a4, a5) = -0.103
# working: q1a08t120dP0_T_96_408
#
# [[Variables]]
#     a1:    -702.136403 +/- 4.13355957 (0.59%) (init = 400)
#     a2:     0.21796708 +/- 0.00247445 (1.14%) (init = 1)
#     a3:     1.2335e-08 +/- 2.51075582 (20355425660.28%) (init = 100)
#     a4:    -1.26254599 +/- 0.00451475 (0.36%) (init = 100)
#     a5:     1.01064064 +/- 4.8465e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01384 (fixed)
#     frd:    0.083594 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.971
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.557
#     C(a3, a5) = -0.546
#     C(a2, a4) =  0.489
#     C(a2, a5) =  0.461
#     C(a3, a4) = -0.390
#     C(a1, a4) =  0.347
# working: q8a08t150dP2_T_120_480
#
# [[Variables]]
#     a1:    -705.145998 +/- 6.41744293 (0.91%) (init = 400)
#     a2:     0.03665747 +/- 0.00285532 (7.79%) (init = 1)
#     a3:     140.990606 +/- 3.76838926 (2.67%) (init = 100)
#     a4:    -1.29384610 +/- 0.00811602 (0.63%) (init = 100)
#     a5:     0.75891787 +/- 5.1668e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013803 (fixed)
#     frd:    0.074863 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -1.000
#     C(a2, a3) = -0.983
#     C(a1, a2) =  0.979
#     C(a3, a4) = -0.886
#     C(a1, a4) =  0.882
#     C(a2, a4) =  0.833
#     C(a2, a5) = -0.173
# working: q1a08t90dPm1_T_96_408
#
# [[Variables]]
#     a1:    -848.938397 +/- 1.89818087 (0.22%) (init = 400)
#     a2:     0.24528940 +/- 0.00117503 (0.48%) (init = 1)
#     a3:     15.5380260 +/- 1.12289198 (7.23%) (init = 100)
#     a4:    -1.17251065 +/- 0.00191295 (0.16%) (init = 100)
#     a5:     1.01558811 +/- 2.0984e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013596 (fixed)
#     frd:    0.088082 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.951
#     C(a1, a5) =  0.588
#     C(a3, a5) = -0.577
#     C(a2, a5) =  0.494
#     C(a2, a4) =  0.301
#     C(a3, a4) = -0.154
#     C(a1, a4) =  0.103
# working: q4a08t150_T_96_360
#
# [[Variables]]
#     a1:    -497.565301 +/- 2.90227911 (0.58%) (init = 400)
#     a2:     0.14608013 +/- 0.00109248 (0.75%) (init = 1)
#     a3:     1.5473e-07 +/- 1.66144412 (1073757497.67%) (init = 100)
#     a4:    -1.08426194 +/- 0.00344417 (0.32%) (init = 100)
#     a5:     0.98402994 +/- 4.7944e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014299 (fixed)
#     frd:    0.065392 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.979
#     C(a1, a2) =  0.969
#     C(a2, a4) =  0.705
#     C(a3, a4) = -0.656
#     C(a1, a4) =  0.624
#     C(a1, a5) =  0.614
#     C(a3, a5) = -0.600
#     C(a2, a5) =  0.507
#     C(a4, a5) =  0.276
# working: q2_a10_a28_ph0_th90
#
# [[Variables]]
#     a1:    -1039.92400 +/- 1.67901012 (0.16%) (init = 400)
#     a2:     0.15986307 +/- 9.7412e-04 (0.61%) (init = 1)
#     a3:     122.589273 +/- 0.98795542 (0.81%) (init = 100)
#     a4:    -1.24007498 +/- 0.00188227 (0.15%) (init = 100)
#     a5:     1.05782266 +/- 2.1134e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013777 (fixed)
#     frd:    0.083085 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.964
#     C(a1, a2) =  0.947
#     C(a1, a5) =  0.578
#     C(a3, a5) = -0.567
#     C(a2, a5) =  0.481
#     C(a2, a4) =  0.313
#     C(a3, a4) = -0.166
#     C(a1, a4) =  0.114
# working: q4a04t120dP0D_T_96_360
#
# [[Variables]]
#     a1:    -740.322818 +/- 1.20874809 (0.16%) (init = 400)
#     a2:     0.19718008 +/- 5.3334e-04 (0.27%) (init = 1)
#     a3:     1.2823e-08 +/- 0.71152985 (5548823484.78%) (init = 100)
#     a4:    -1.16560021 +/- 0.00142026 (0.12%) (init = 100)
#     a5:     1.02000564 +/- 1.8744e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01415 (fixed)
#     frd:    0.07059 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.973
#     C(a1, a2) =  0.961
#     C(a1, a5) =  0.601
#     C(a3, a5) = -0.587
#     C(a2, a4) =  0.586
#     C(a3, a4) = -0.504
#     C(a2, a5) =  0.495
#     C(a1, a4) =  0.463
#     C(a4, a5) =  0.170
# working: q2a04t90dPm1_T_96_408
#
# [[Variables]]
#     a1:    -828.071133 +/- 2.06331698 (0.25%) (init = 400)
#     a2:     0.23903822 +/- 0.00122580 (0.51%) (init = 1)
#     a3:     5.88853337 +/- 1.22564231 (20.81%) (init = 100)
#     a4:    -1.19123247 +/- 0.00226751 (0.19%) (init = 100)
#     a5:     1.01579183 +/- 2.5928e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013775 (fixed)
#     frd:    0.083133 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.970
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.555
#     C(a3, a5) = -0.543
#     C(a2, a4) =  0.482
#     C(a2, a5) =  0.459
#     C(a3, a4) = -0.381
#     C(a1, a4) =  0.337
# working: q8a04t60D_dPm1
#
# [[Variables]]
#     a1:    -1328.23819 +/- 1.84168700 (0.14%) (init = 400)
#     a2:     0.27278892 +/- 7.9733e-04 (0.29%) (init = 1)
#     a3:     1.7009e-08 +/- 0.27125418 (1594804455.61%) (init = 100)
#     a4:    -1.12882380 +/- 0.00216552 (0.19%) (init = 100)
#     a5:     1.06656909 +/- 3.0863e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014002 (fixed)
#     frd:    0.070492 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.966
#     C(a1, a2) =  0.950
#     C(a1, a5) =  0.623
#     C(a3, a5) =  0.611
#     C(a2, a5) =  0.515
#     C(a2, a4) =  0.415
#     C(a3, a4) =  0.283
#     C(a1, a4) =  0.229
# working: q1a04t120_dP0_T_96_552
#
# [[Variables]]
#     a1:    -737.744833 +/- 4.21864759 (0.57%) (init = 400)
#     a2:     0.23203692 +/- 0.00258746 (1.12%) (init = 1)
#     a3:     1.6553e-08 +/- 0.22313916 (1347993886.96%) (init = 100)
#     a4:    -1.22970776 +/- 0.00440626 (0.36%) (init = 100)
#     a5:     1.00255022 +/- 4.7287e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013724 (fixed)
#     frd:    0.085809 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.970
#     C(a1, a2) =  0.957
#     C(a1, a5) =  0.566
#     C(a3, a5) =  0.554
#     C(a2, a5) =  0.470
#     C(a2, a4) =  0.448
#     C(a3, a4) =  0.337
#     C(a1, a4) =  0.292

# %%
fits[0]
# Out:
# <h2> Model</h2> Model(dphimrd_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>201</td><td></td></tr><tr><td># data points</td><td>2338</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 32122.2670</td><td></td></tr><tr><td>reduced chi-square</td><td> 13.7686528</td><td></td></tr><tr><td>Akaike info crit.</td><td> 6136.15292</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 6164.93818</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a1 </td><td> -964.964073 </td><td>  3.87000618 </td><td> (0.40%) </td><td> 400 </td><td> -100000.000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a2 </td><td>  0.25536553 </td><td>  0.00177870 </td><td> (0.70%) </td><td> 1 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a3 </td><td>  1.2546e-09 </td><td>  0.07305507 </td><td> (5823199529.43%) </td><td> 100 </td><td>  0.00000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a4 </td><td> -1.19517795 </td><td>  0.00471877 </td><td> (0.39%) </td><td> 100 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a5 </td><td>  1.12222616 </td><td>  6.0397e-04 </td><td> (0.05%) </td><td> 1 </td><td> -6.00000000 </td><td>  6.00000000 </td><td> True </td></tr><tr><td> a6 </td><td>  1.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1 </td><td> -10.0000000 </td><td>  10.0000000 </td><td> False </td></tr><tr><td> fdamp </td><td>  0.01400900 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.014009 </td><td>  0.00280180 </td><td>  0.07004500 </td><td> False </td></tr><tr><td> frd </td><td>  0.07420500 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.074205 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a1</td><td>a3</td><td>0.9976</td></tr><tr><td>a2</td><td>a3</td><td>0.9562</td></tr><tr><td>a1</td><td>a2</td><td>0.9364</td></tr><tr><td>a1</td><td>a5</td><td>0.6251</td></tr><tr><td>a3</td><td>a5</td><td>0.6160</td></tr><tr><td>a2</td><td>a5</td><td>0.5262</td></tr><tr><td>a2</td><td>a4</td><td>0.1590</td></tr><tr><td>a4</td><td>a5</td><td>-0.1208</td></tr></table>

# %%
fits[0].params['a1'].value
# Out:
# -964.9640732026601

# %%
wfs[0].eta
# Out:
# 0.16000039999600005

# %%
wfs[0].X1
# Out:
# array([-7.27303692e-04,  7.99961251e-01, -5.49319079e-03])

# %%
def cart_to_polar(x, y, z):
    """
    cartesian to spherical polar transformation
    returns: r, theta, phi
    """
    hxy = np.hypot(x, y)
    r = np.hypot(hxy, z)
    theta = np.arctan2(hxy, z)
    phi = np.arctan2(y, x)
    return r, theta, phi

# %%
psf_coords = []
for wf in wfs:
    r, theta, phi = cart_to_polar(*wf.X1)
#     psf_coords.append([wf.eta, r, theta, phi])
#     psf_coords.append([wf.eta, r])
#     psf_coords.append([wf.eta, theta])
#     psf_coords.append([wf.eta, np.cos(theta)])
    psf_coords.append([wf.eta, np.cos(theta), r])
#     psf_coords.append([wf.eta, phi])
#     psf_coords.append([wf.eta, wf.X1[0]])
#     psf_coords.append([wf.eta, wf.X1[1]])
#     psf_coords.append([wf.eta, wf.X1[2]])
psf_coords = np.array(psf_coords)

# %%
psf_coords
# Out:
# array([[ 1.60000400e-01, -6.86665637e-03,  7.99980442e-01],
#        [ 2.22222778e-01,  8.05327355e-01,  3.99991541e-01],
#        [ 9.87654444e-02,  6.11707978e-03,  7.99985695e-01],
#        [ 1.60000200e-01, -1.80827695e-04,  3.99994224e-01],
#        [ 2.22223111e-01, -4.52626969e-01,  7.99977434e-01],
#        [ 9.87653827e-02, -7.96287068e-01,  3.99997142e-01],
#        [ 1.60000400e-01,  4.65013824e-01,  7.99979739e-01],
#        [ 2.22223111e-01,  8.62400521e-01,  7.99976827e-01],
#        [ 2.22222778e-01, -3.30999947e-01,  3.99992162e-01],
#        [ 1.60000200e-01,  4.92715221e-01,  3.99994694e-01],
#        [ 2.22222778e-01, -5.76191041e-01,  3.99992545e-01],
#        [ 1.60000400e-01,  6.88431589e-01,  7.99980060e-01],
#        [ 2.50000000e-01,  8.35069297e-01,  7.99971874e-01],
#        [ 2.22223111e-01,  3.69548480e-01,  7.99977507e-01],
#        [ 9.87654444e-02,  2.64786048e-01,  7.99985714e-01],
#        [ 2.22222778e-01,  3.81258462e-01,  3.99991916e-01],
#        [ 1.60000400e-01, -4.27339816e-01,  7.99980052e-01],
#        [ 2.50000000e-01, -5.82720129e-01,  7.99971024e-01],
#        [ 2.50000000e-01,  4.88244437e-01,  7.99970485e-01],
#        [ 9.87654444e-02,  8.62409231e-01,  7.99985678e-01],
#        [ 9.87653827e-02, -2.89005061e-03,  3.99997327e-01],
#        [ 2.50000000e-01, -7.03956819e-04,  3.99990503e-01],
#        [ 9.87662099e-02,  4.49904477e-01,  7.99988818e-01],
#        [ 9.87653827e-02,  2.30806812e-01,  3.99997472e-01],
#        [ 9.87653827e-02, -2.69286667e-01,  3.99997271e-01],
#        [ 1.60000200e-01, -8.64292215e-01,  3.99995349e-01],
#        [ 1.60000200e-01,  4.39109243e-01,  3.99995120e-01],
#        [ 2.50000000e-01,  4.97416933e-01,  3.99990454e-01],
#        [ 2.22223111e-01, -8.60616973e-01,  7.99977219e-01],
#        [ 2.50000000e-01, -8.64231942e-01,  3.99990427e-01],
#        [ 2.50000000e-01,  8.65455397e-01,  3.99990217e-01],
#        [ 2.50000000e-01, -4.99958686e-01,  7.99971703e-01],
#        [ 9.87654444e-02,  3.30834258e-01,  7.99985684e-01],
#        [ 2.50000000e-01, -5.14869609e-04,  7.99971808e-01],
#        [ 1.60002280e-01, -6.09487866e-01,  7.99982545e-01],
#        [ 2.22223111e-01, -4.04330143e-03,  7.99978555e-01],
#        [ 1.60000200e-01, -4.45222104e-01,  3.99995496e-01],
#        [ 2.22222778e-01, -2.02830653e-03,  3.99991481e-01],
#        [ 9.87653827e-02,  2.84771123e-01,  3.99997032e-01],
#        [ 2.50000000e-01, -4.86476032e-01,  3.99990374e-01]])

# %%
params = fits[0].params

# %%
psf_data={}
for k in params.keys():
    if fits[0].params[k].vary:
        v = np.array([fits[i].params[k].value for i in range(len(fits))])
        psf_data.update({k:v})

# %%
psf_data.keys()
# Out:
# dict_keys(['a1', 'a2', 'a3', 'a4', 'a5'])

# %%
psf_data['a1']
# Out:
# array([ -964.9640732 , -1016.81710189, -1119.28376685,  -904.60871035,
#         -672.89485187,  -662.21913957, -1463.68222135, -1485.0046916 ,
#         -717.45524114, -1062.96307073,  -663.00489053, -1833.92461044,
#        -1146.921962  , -1196.86278724,  -648.77015245,  -951.32223056,
#         -654.89925379,  -619.18365779,  -962.76206669, -2778.07440847,
#        -1013.69862399,  -796.62912202, -2006.68191085, -1600.26855335,
#         -779.5861559 ,  -652.31647216, -1223.60170898,  -868.83218565,
#         -593.67410353,  -696.09525611,  -948.18696467,  -702.13640298,
#         -705.14599772,  -848.93839655,  -497.56530112, -1039.92400173,
#         -740.32281778,  -828.07113282, -1328.23818544,  -737.74483324])

# %%
psf_coords[:,0]
# Out:
# array([0.1600004 , 0.22222278, 0.09876544, 0.1600002 , 0.22222311,
#        0.09876538, 0.1600004 , 0.22222311, 0.22222278, 0.1600002 ,
#        0.22222278, 0.1600004 , 0.25      , 0.22222311, 0.09876544,
#        0.22222278, 0.1600004 , 0.25      , 0.25      , 0.09876544,
#        0.09876538, 0.25      , 0.09876621, 0.09876538, 0.09876538,
#        0.1600002 , 0.1600002 , 0.25      , 0.22222311, 0.25      ,
#        0.25      , 0.25      , 0.09876544, 0.25      , 0.16000228,
#        0.22222311, 0.1600002 , 0.22222278, 0.09876538, 0.25      ])

# %%
for k in psf_data.keys():
    plt.figure()
    plt.scatter(psf_coords[:,1], psf_data[k][:])
    plt.title(k)
    plt.show()
    plt.close()

# %%
# eta_target = 0.0987
eta_target = 0.16
mask = (psf_coords[:,0] > eta_target-1e-3) & (psf_coords[:,0] < eta_target+1e-3)
for k in psf_data.keys():
    plt.figure()
    plt.scatter(psf_coords[mask,1], psf_data[k][mask])
    plt.title(k)
    plt.show()
    plt.close()

# %%
for k in psf_data.keys():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(psf_coords[:,0], psf_coords[:,1], psf_data[k])
    ax.set_title(k)
    fig.show()

# %%
for k in psf_data.keys():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(psf_coords[:,2], psf_coords[:,1], psf_data[k])
    ax.set_title(k)
    fig.show()

# %%
# q, chi, costheta

# %%
pwd
# Out:
# '/nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk'

# %%
# np.savetxt("psf_phase_x.txt", psf_coords)

# %%
# psf_y = np.array([psf_data[k] for k in psf_data.keys()]).T

# %%
# np.savetxt("psf_phase_y.txt", psf_y)

# %%
# psf_coords = np.loadtxt("psf_phase_x.txt")

# %%
# psf_y = np.loadtxt("psf_phase_y.txt")

# %%
# psf_y.shape

# %%
# plt.figure()
# plt.scatter(psf_coords[:,1], psf_y[:,2])

# %%
# psf_coords[0]
