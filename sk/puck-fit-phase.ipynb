# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 16}) 

import h5py
import numpy as np

from scipy.interpolate import InterpolatedUnivariateSpline as IUS

# %%
import os

# %%
import phenom
import numpy as np

# %%
import puck

# %%
from ansatz import dphimrd_func

# %%
# wf = puck.Waveform(filename='data/q1a04t120_dP0_T_96_552.h5')
wf = puck.Waveform(filename='data/q4a08t90dPm1D_T_96_384.h5')

# %%
wf.info
# Out:
# simname: q4a08t90dPm1D_T_96_384
# filename: data/q4a08t90dPm1D_T_96_384.h5
# eta: 0.16000039999600005
# X1: [-7.27303692e-04  7.99961251e-01 -5.49319079e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.977977
# assuming non-precessing:
# (non-prec) final spin: 0.468547
# (non-prec) ringdown freq: 0.074205
# (non-prec) ringdown damp: 0.014009
# estimated using PhenomP final spin:
# (prec) final spin: 0.711389
# (prec) ringdown freq: 0.087515
# (prec) ringdown damp: 0.013076

# %%
wf.compute_fft(t12=[-1500, -1000], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.01, f_max=0.14)
# wf.compute_fft(t12=[-1000, -500], t34=[100, 101], plot=True, take_pos_f=True, f_min=0.01, f_max=0.3)
# Out:
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))

# %%
wf.plot_fd(xlim=[0.01,0.12])

# %%
wf.plot_td(xlim=[-600,100])
# wf.plot_td()

# %% [markdown]
# # loop over all

# %%
import glob
all_files = glob.glob('data/*.h5')

# %%
len(all_files)
# Out:
# 40

# %%
all_files
# Out:
# ['data/q4a08t90dPm1D_T_96_384.h5',
#  'data/q2a04t30dPm2_T_96_408.h5',
#  'data/q8a08t90dP0_T_96_384.h5',
#  'data/q4a04t90_T_96_360.h5',
#  'data/q2_a10_a28_ph0_th120.h5',
#  'data/q8a04t150dP9_T_96_360.h5',
#  'data/q4a08t60dPm3dRm250_T_96_384.h5',
#  'data/q2_a10_a28_ph0_th30.h5',
#  'data/q2a04t120_T_96_408.h5',
#  'data/q4a04t60dPm1.5D_T_96_360.h5',
#  'data/q2a04t150_T_96_408.h5',
#  'data/q4a08t30dPm5p5dRm47_T_96_360.h5',
#  'data/q1a08t30dPm25_T_96_408.h5',
#  'data/q2_a10_a28_ph0_th60.h5',
#  'data/q8a08t120dP2_r03_T_96_360.h5',
#  'data/q2a04t60dPm1_T_96_408.h5',
#  'data/q4a08t120dP1_T_96_360.h5',
#  'data/q1a08t150dP0_T_96_408.h5',
#  'data/q1a08t60dPm1.5_T_96_408.h5',
#  'data/q8a08t30dPm9.35_r0.5_T_96_360.h5',
#  'data/q8a04t90dP0_T_96_360.h5',
#  'data/q1a04t90_dP0_T_96_552.h5',
#  'data/q8a08t60Ditm45dr075_96_360.h5',
#  'data/q8a04t30dPm3_T_96_360.h5',
#  'data/q8a04t120dPp1_T_96_360.h5',
#  'data/q4a04t150_T_96_360.h5',
#  'data/q4a04t30_T_96_360.h5',
#  'data/q1a04t60_dPm1_T_96_552.h5',
#  'data/q2_a10_a28_ph0_th150.h5',
#  'data/q1a04t150_dP0_T_96_552.h5',
#  'data/q1a04t30_dPm2_T_96_552.h5',
#  'data/q1a08t120dP0_T_96_408.h5',
#  'data/q8a08t150dP2_T_120_480.h5',
#  'data/q1a08t90dPm1_T_96_408.h5',
#  'data/q4a08t150_T_96_360.h5',
#  'data/q2_a10_a28_ph0_th90.h5',
#  'data/q4a04t120dP0D_T_96_360.h5',
#  'data/q2a04t90dPm1_T_96_408.h5',
#  'data/q8a04t60D_dPm1.h5',
#  'data/q1a04t120_dP0_T_96_552.h5']

# %%
all_files[0]
# Out:
# 'data/q4a08t90dPm1D_T_96_384.h5'

# %%
wfs = []
for i, f in enumerate(all_files):
    print(f"working: {i}/{len(all_files)}")
#     if "q8a08t150dP2_T_96_360" in f:
#         continue
#     if "q8a04t60D_dPm1" in f:
#         continue
    wf = puck.Waveform(filename=f)
    print("info:")
    wf.info
    print("\n")
    
#     wf.compute_fft(t12=[-1400, -1000], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.025, f_max=0.14)
    wf.compute_fft(t12=[-1500, -800], t34=[100, 150], plot=True, take_pos_f=True, f_min=0.018, f_max=0.12)
    
    wfs.append(wf)
# Out:
# working: 0/40
# info:
# simname: q4a08t90dPm1D_T_96_384
# filename: data/q4a08t90dPm1D_T_96_384.h5
# eta: 0.16000039999600005
# X1: [-7.27303692e-04  7.99961251e-01 -5.49319079e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.977977
# assuming non-precessing:
# (non-prec) final spin: 0.468547
# (non-prec) ringdown freq: 0.074205
# (non-prec) ringdown damp: 0.014009
# estimated using PhenomP final spin:
# (prec) final spin: 0.711389
# (prec) ringdown freq: 0.087515
# (prec) ringdown damp: 0.013076
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 1/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q2a04t30dPm2_T_96_408
# filename: data/q2a04t30dPm2_T_96_408.h5
# eta: 0.22222277777233335
# X1: [0.12702494 0.20023472 0.32212413]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.954422
# assuming non-precessing:
# (non-prec) final spin: 0.720741
# (non-prec) ringdown freq: 0.090406
# (non-prec) ringdown damp: 0.013334
# estimated using PhenomP final spin:
# (prec) final spin: 0.729968
# (prec) ringdown freq: 0.09115
# (prec) ringdown damp: 0.013266
# working: 2/40
# info:
# simname: q8a08t90dP0_T_96_384
# filename: data/q8a08t90dP0_T_96_384.h5
# eta: 0.09876544444344446
# X1: [0.00713932 0.79993887 0.00489358]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.98938
# assuming non-precessing:
# (non-prec) final spin: 0.310634
# (non-prec) ringdown freq: 0.067809
# (non-prec) ringdown damp: 0.0141
# estimated using PhenomP final spin:
# (prec) final spin: 0.716551
# (prec) ringdown freq: 0.086893
# (prec) ringdown damp: 0.012891
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 3/40
# info:
# simname: q4a04t90_T_96_360
# filename: data/q4a04t90_T_96_360.h5
# eta: 0.160000199999
# X1: [-1.36875477e-03  3.99991875e-01 -7.23300334e-05]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.97791
# assuming non-precessing:
# (non-prec) final spin: 0.47145
# (non-prec) ringdown freq: 0.074329
# (non-prec) ringdown damp: 0.014004
# estimated using PhenomP final spin:
# (prec) final spin: 0.542148
# (prec) ringdown freq: 0.077455
# (prec) ringdown damp: 0.013825
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 4/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q2_a10_a28_ph0_th120
# filename: data/q2_a10_a28_ph0_th120.h5
# eta: 0.22222311110000012
# X1: [-0.17521407  0.69148664 -0.36209136]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.966642
# assuming non-precessing:
# (non-prec) final spin: 0.51029
# (non-prec) ringdown freq: 0.076875
# (non-prec) ringdown damp: 0.014074
# estimated using PhenomP final spin:
# (prec) final spin: 0.612795
# (prec) ringdown freq: 0.082062
# (prec) ringdown damp: 0.013741
# working: 5/40
# info:
# simname: q8a04t150dP9_T_96_360
# filename: data/q8a04t150dP9_T_96_360.h5
# eta: 0.09876538271585186
# X1: [ 0.13749907  0.19910167 -0.31851255]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.991079
# assuming non-precessing:
# (non-prec) final spin: 0.07237
# (non-prec) ringdown freq: 0.061532
# (non-prec) ringdown damp: 0.014258
# estimated using PhenomP final spin:
# (prec) final spin: 0.207659
# (prec) ringdown freq: 0.064779
# (prec) ringdown damp: 0.014176
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 6/40
# info:
# simname: q4a08t60dPm3dRm250_T_96_384
# filename: data/q4a08t60dPm3dRm250_T_96_384.h5
# eta: 0.16000039999600005
# X1: [0.13490444 0.69525762 0.37200164]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.971768
# assuming non-precessing:
# (non-prec) final spin: 0.666849
# (non-prec) ringdown freq: 0.084933
# (non-prec) ringdown damp: 0.013421
# estimated using PhenomP final spin:
# (prec) final spin: 0.821626
# (prec) ringdown freq: 0.098389
# (prec) ringdown damp: 0.012119
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 7/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q2_a10_a28_ph0_th30
# filename: data/q2_a10_a28_ph0_th30.h5
# eta: 0.22222311110000012
# X1: [-0.05550302  0.40114802  0.68990043]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.942401
# assuming non-precessing:
# (non-prec) final spin: 0.824729
# (non-prec) ringdown freq: 0.101833
# (non-prec) ringdown damp: 0.012453
# estimated using PhenomP final spin:
# (prec) final spin: 0.849263
# (prec) ringdown freq: 0.105049
# (prec) ringdown damp: 0.01207
# working: 8/40
# info:
# simname: q2a04t120_T_96_408
# filename: data/q2a04t120_T_96_408.h5
# eta: 0.22222277777233335
# X1: [ 0.15059256  0.34610192 -0.13239738]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.963432
# assuming non-precessing:
# (non-prec) final spin: 0.582506
# (non-prec) ringdown freq: 0.080665
# (non-prec) ringdown damp: 0.013902
# estimated using PhenomP final spin:
# (prec) final spin: 0.609898
# (prec) ringdown freq: 0.08217
# (prec) ringdown damp: 0.013799
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 9/40
# info:
# simname: q4a04t60dPm1.5D_T_96_360
# filename: data/q4a04t60dPm1.5D_T_96_360.h5
# eta: 0.160000199999
# X1: [0.02692763 0.34702847 0.19708347]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.975101
# assuming non-precessing:
# (non-prec) final spin: 0.576216
# (non-prec) ringdown freq: 0.079372
# (non-prec) ringdown damp: 0.013757
# estimated using PhenomP final spin:
# (prec) final spin: 0.622025
# (prec) ringdown freq: 0.081879
# (prec) ringdown damp: 0.013585
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 10/40
# info:
# simname: q2a04t150_T_96_408
# filename: data/q2a04t150_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-0.25890258  0.19961486 -0.23047212]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.964885
# assuming non-precessing:
# (non-prec) final spin: 0.551813
# (non-prec) ringdown freq: 0.078973
# (non-prec) ringdown damp: 0.013982
# estimated using PhenomP final spin:
# (prec) final spin: 0.573458
# (prec) ringdown freq: 0.080068
# (prec) ringdown damp: 0.013912
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 11/40
# info:
# simname: q4a08t30dPm5p5dRm47_T_96_360
# filename: data/q4a08t30dPm5p5dRm47_T_96_360.h5
# eta: 0.16000039999600005
# X1: [0.41810205 0.40231025 0.55073154]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.967059
# assuming non-precessing:
# (non-prec) final spin: 0.755626
# (non-prec) ringdown freq: 0.092133
# (non-prec) ringdown damp: 0.012889
# estimated using PhenomP final spin:
# (prec) final spin: 0.853603
# (prec) ringdown freq: 0.10297
# (prec) ringdown damp: 0.011688
# working: 12/40
# info:
# simname: q1a08t30dPm25_T_96_408
# filename: data/q1a08t30dPm25_T_96_408.h5
# eta: 0.25
# X1: [-0.18281502 -0.40033359  0.66803195]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.940355
# assuming non-precessing:
# (non-prec) final spin: 0.785548
# (non-prec) ringdown freq: 0.097649
# (non-prec) ringdown damp: 0.012963
# estimated using PhenomP final spin:
# (prec) final spin: 0.795341
# (prec) ringdown freq: 0.098678
# (prec) ringdown damp: 0.012854
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 13/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q2_a10_a28_ph0_th60
# filename: data/q2_a10_a28_ph0_th60.h5
# eta: 0.22222311110000012
# X1: [-0.26675028  0.69383782  0.29563047]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.955082
# assuming non-precessing:
# (non-prec) final spin: 0.712922
# (non-prec) ringdown freq: 0.089731
# (non-prec) ringdown damp: 0.013379
# estimated using PhenomP final spin:
# (prec) final spin: 0.799645
# (prec) ringdown freq: 0.097616
# (prec) ringdown damp: 0.012607
# working: 14/40
# info:
# simname: q8a08t120dP2_r03_T_96_360
# filename: data/q8a08t120dP2_r03_T_96_360.h5
# eta: 0.09876544444344446
# X1: [-0.34656989  0.68919997  0.21182506]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.98779
# assuming non-precessing:
# (non-prec) final spin: 0.462669
# (non-prec) ringdown freq: 0.073231
# (non-prec) ringdown damp: 0.013882
# estimated using PhenomP final spin:
# (prec) final spin: 0.777366
# (prec) ringdown freq: 0.092172
# (prec) ringdown damp: 0.012422
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 15/40
# info:
# simname: q2a04t60dPm1_T_96_408
# filename: data/q2a04t60dPm1_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-0.12855603  0.34671391  0.1525003 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.958315
# assuming non-precessing:
# (non-prec) final spin: 0.670091
# (non-prec) ringdown freq: 0.086343
# (non-prec) ringdown damp: 0.013592
# estimated using PhenomP final spin:
# (prec) final spin: 0.693575
# (prec) ringdown freq: 0.087983
# (prec) ringdown damp: 0.013458
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 16/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q4a08t120dP1_T_96_360
# filename: data/q4a08t120dP1_T_96_360.h5
# eta: 0.16000039999600005
# X1: [-0.2159821   0.69025306 -0.34186333]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.981335
# assuming non-precessing:
# (non-prec) final spin: 0.287549
# (non-prec) ringdown freq: 0.067665
# (non-prec) ringdown damp: 0.014242
# estimated using PhenomP final spin:
# (prec) final spin: 0.560104
# (prec) ringdown freq: 0.078055
# (prec) ringdown damp: 0.013722
# working: 17/40
# info:
# simname: q1a08t150dP0_T_96_408
# filename: data/q1a08t150dP0_T_96_408.h5
# eta: 0.25
# X1: [-0.51296553 -0.39939402 -0.46615922]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.957178
# assuming non-precessing:
# (non-prec) final spin: 0.61355
# (non-prec) ringdown freq: 0.082917
# (non-prec) ringdown damp: 0.013874
# estimated using PhenomP final spin:
# (prec) final spin: 0.63868
# (prec) ringdown freq: 0.084418
# (prec) ringdown damp: 0.013765
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 18/40
# info:
# simname: q1a08t60dPm1.5_T_96_408
# filename: data/q1a08t60dPm1.5_T_96_408.h5
# eta: 0.25
# X1: [-0.08390818 -0.69307905  0.39058114]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.945632
# assuming non-precessing:
# (non-prec) final spin: 0.745271
# (non-prec) ringdown freq: 0.093299
# (non-prec) ringdown damp: 0.013269
# estimated using PhenomP final spin:
# (prec) final spin: 0.770405
# (prec) ringdown freq: 0.095602
# (prec) ringdown damp: 0.013044
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 19/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q8a08t30dPm9.35_r0.5_T_96_360
# filename: data/q8a08t30dPm9.35_r0.5_T_96_360.h5
# eta: 0.09876544444344446
# X1: [0.03222868 0.40367765 0.68991503]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.980372
# assuming non-precessing:
# (non-prec) final spin: 0.792449
# (non-prec) ringdown freq: 0.094354
# (non-prec) ringdown damp: 0.012361
# estimated using PhenomP final spin:
# (prec) final spin: 0.859538
# (prec) ringdown freq: 0.102405
# (prec) ringdown damp: 0.011424
# working: 20/40
# info:
# simname: q8a04t90dP0_T_96_360
# filename: data/q8a04t90dP0_T_96_360.h5
# eta: 0.09876538271585186
# X1: [ 0.00178953  0.39999165 -0.00115601]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.989419
# assuming non-precessing:
# (non-prec) final spin: 0.306166
# (non-prec) ringdown freq: 0.06767
# (non-prec) ringdown damp: 0.014105
# estimated using PhenomP final spin:
# (prec) final spin: 0.444932
# (prec) ringdown freq: 0.072415
# (prec) ringdown damp: 0.013895
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 21/40
# info:
# simname: q1a04t90_dP0_T_96_552
# filename: data/q1a04t90_dP0_T_96_552.h5
# eta: 0.25
# X1: [-5.32667216e-05  3.99990400e-01 -2.81576042e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.951616
# assuming non-precessing:
# (non-prec) final spin: 0.686374
# (non-prec) ringdown freq: 0.088083
# (non-prec) ringdown damp: 0.013596
# estimated using PhenomP final spin:
# (prec) final spin: 0.6952
# (prec) ringdown freq: 0.088721
# (prec) ringdown damp: 0.013542
# working: 22/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q8a08t60Ditm45dr075_96_360
# filename: data/q8a08t60Ditm45dr075_96_360.h5
# eta: 0.09876620987653086
# X1: [0.15898056 0.69653853 0.35991855]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.986249
# assuming non-precessing:
# (non-prec) final spin: 0.569392
# (non-prec) ringdown freq: 0.078128
# (non-prec) ringdown damp: 0.013624
# estimated using PhenomP final spin:
# (prec) final spin: 0.81303
# (prec) ringdown freq: 0.095971
# (prec) ringdown damp: 0.012051
# working: 23/40
# info:
# simname: q8a04t30dPm3_T_96_360
# filename: data/q8a04t30dPm3_T_96_360.h5
# eta: 0.09876538271585186
# X1: [0.33332279 0.20092416 0.09232214]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.988771
# assuming non-precessing:
# (non-prec) final spin: 0.375105
# (non-prec) ringdown freq: 0.069932
# (non-prec) ringdown damp: 0.014024
# estimated using PhenomP final spin:
# (prec) final spin: 0.489529
# (prec) ringdown freq: 0.07426
# (prec) ringdown damp: 0.013809
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 24/40
# info:
# simname: q8a04t120dPp1_T_96_360
# filename: data/q8a04t120dPp1_T_96_360.h5
# eta: 0.09876538271585186
# X1: [-0.17037978  0.34549422 -0.10771393]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.990056
# assuming non-precessing:
# (non-prec) final spin: 0.227452
# (non-prec) ringdown freq: 0.065373
# (non-prec) ringdown damp: 0.014174
# estimated using PhenomP final spin:
# (prec) final spin: 0.38491
# (prec) ringdown freq: 0.070177
# (prec) ringdown damp: 0.013991
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 25/40
# info:
# simname: q4a04t150_T_96_360
# filename: data/q4a04t150_T_96_360.h5
# eta: 0.160000199999
# X1: [-0.02705529  0.19936626 -0.34571287]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.981367
# assuming non-precessing:
# (non-prec) final spin: 0.285477
# (non-prec) ringdown freq: 0.067602
# (non-prec) ringdown damp: 0.014244
# estimated using PhenomP final spin:
# (prec) final spin: 0.315234
# (prec) ringdown freq: 0.068505
# (prec) ringdown damp: 0.01421
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 26/40
# info:
# simname: q4a04t30_T_96_360
# filename: data/q4a04t30_T_96_360.h5
# eta: 0.160000199999
# X1: [-0.2981619   0.20061312  0.17564155]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.975448
# assuming non-precessing:
# (non-prec) final spin: 0.564927
# (non-prec) ringdown freq: 0.078768
# (non-prec) ringdown damp: 0.01379
# estimated using PhenomP final spin:
# (prec) final spin: 0.614468
# (prec) ringdown freq: 0.081416
# (prec) ringdown damp: 0.013611
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 27/40
# info:
# simname: q1a04t60_dPm1_T_96_552
# filename: data/q1a04t60_dPm1_T_96_552.h5
# eta: 0.25
# X1: [-0.01989968  0.34642529  0.19896202]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.948747
# assuming non-precessing:
# (non-prec) final spin: 0.716681
# (non-prec) ringdown freq: 0.090625
# (non-prec) ringdown damp: 0.013442
# estimated using PhenomP final spin:
# (prec) final spin: 0.723132
# (prec) ringdown freq: 0.091139
# (prec) ringdown damp: 0.013396
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 28/40
# info:
# simname: q2_a10_a28_ph0_th150
# filename: data/q2_a10_a28_ph0_th150.h5
# eta: 0.22222311110000012
# X1: [ 0.08533201  0.3983536  -0.68847397]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.970244
# assuming non-precessing:
# (non-prec) final spin: 0.405969
# (non-prec) ringdown freq: 0.072367
# (non-prec) ringdown damp: 0.014242
# estimated using PhenomP final spin:
# (prec) final spin: 0.449226
# (prec) ringdown freq: 0.074016
# (prec) ringdown damp: 0.014161
# working: 29/40
# info:
# simname: q1a04t150_dP0_T_96_552
# filename: data/q1a04t150_dP0_T_96_552.h5
# eta: 0.25
# X1: [-0.02297821  0.1999164  -0.3456845 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.955872
# assuming non-precessing:
# (non-prec) final spin: 0.632621
# (non-prec) ringdown freq: 0.084162
# (non-prec) ringdown damp: 0.013811
# estimated using PhenomP final spin:
# (prec) final spin: 0.635012
# (prec) ringdown freq: 0.084307
# (prec) ringdown damp: 0.013801
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 30/40
# info:
# simname: q1a04t30_dPm2_T_96_552
# filename: data/q1a04t30_dPm2_T_96_552.h5
# eta: 0.25
# X1: [-0.01213047  0.200022    0.34617369]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.946388
# assuming non-precessing:
# (non-prec) final spin: 0.738698
# (non-prec) ringdown freq: 0.092657
# (non-prec) ringdown damp: 0.013311
# estimated using PhenomP final spin:
# (prec) final spin: 0.740812
# (prec) ringdown freq: 0.092838
# (prec) ringdown damp: 0.013295
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 31/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q1a08t120dP0_T_96_408
# filename: data/q1a08t120dP0_T_96_408.h5
# eta: 0.25
# X1: [ 0.02445732 -0.69238307 -0.3999528 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.95647
# assuming non-precessing:
# (non-prec) final spin: 0.624049
# (non-prec) ringdown freq: 0.083594
# (non-prec) ringdown damp: 0.01384
# estimated using PhenomP final spin:
# (prec) final spin: 0.652137
# (prec) ringdown freq: 0.085327
# (prec) ringdown damp: 0.013711
# working: 32/40
# info:
# simname: q8a08t150dP2_T_120_480
# filename: data/q8a08t150dP2_T_120_480.h5
# eta: 0.09876544444344446
# X1: [0.64241193 0.39653206 0.26466267]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.987288
# assuming non-precessing:
# (non-prec) final spin: 0.501033
# (non-prec) ringdown freq: 0.074863
# (non-prec) ringdown damp: 0.013803
# estimated using PhenomP final spin:
# (prec) final spin: 0.790899
# (prec) ringdown freq: 0.093538
# (prec) ringdown damp: 0.012291
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 33/40
# info:
# simname: q1a08t90dPm1_T_96_408
# filename: data/q1a08t90dPm1_T_96_408.h5
# eta: 0.25
# X1: [ 8.95531761e-04 -7.99971201e-01 -4.11881172e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.951618
# assuming non-precessing:
# (non-prec) final spin: 0.686354
# (non-prec) ringdown freq: 0.088082
# (non-prec) ringdown damp: 0.013596
# estimated using PhenomP final spin:
# (prec) final spin: 0.721009
# (prec) ringdown freq: 0.090694
# (prec) ringdown damp: 0.013371
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 34/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q4a08t150_T_96_360
# filename: data/q4a08t150_T_96_360.h5
# eta: 0.16000227999963998
# X1: [ 0.494267    0.3974145  -0.48757965]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.982432
# assuming non-precessing:
# (non-prec) final spin: 0.209253
# (non-prec) ringdown freq: 0.065392
# (non-prec) ringdown damp: 0.014299
# estimated using PhenomP final spin:
# (prec) final spin: 0.469729
# (prec) ringdown freq: 0.073916
# (prec) ringdown damp: 0.013943
# working: 35/40
# info:
# simname: q2_a10_a28_ph0_th90
# filename: data/q2_a10_a28_ph0_th90.h5
# eta: 0.22222311110000012
# X1: [ 5.14092605e-04  7.99971851e-01 -3.23455443e-03]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.961296
# assuming non-precessing:
# (non-prec) final spin: 0.622541
# (non-prec) ringdown freq: 0.083085
# (non-prec) ringdown damp: 0.013777
# estimated using PhenomP final spin:
# (prec) final spin: 0.731838
# (prec) ringdown freq: 0.090651
# (prec) ringdown damp: 0.013158
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 36/40
# info:
# simname: q4a04t120dP0D_T_96_360
# filename: data/q4a04t120dP0D_T_96_360.h5
# eta: 0.160000199999
# X1: [ 0.09332774  0.34579099 -0.17808684]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.979871
# assuming non-precessing:
# (non-prec) final spin: 0.375761
# (non-prec) ringdown freq: 0.07059
# (non-prec) ringdown damp: 0.01415
# estimated using PhenomP final spin:
# (prec) final spin: 0.445188
# (prec) ringdown freq: 0.07313
# (prec) ringdown damp: 0.01403
# working: 37/40
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# info:
# simname: q2a04t90dPm1_T_96_408
# filename: data/q2a04t90dPm1_T_96_408.h5
# eta: 0.22222277777233335
# X1: [-8.23707099e-05  3.99990650e-01 -8.11305335e-04]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.961253
# assuming non-precessing:
# (non-prec) final spin: 0.623287
# (non-prec) ringdown freq: 0.083133
# (non-prec) ringdown damp: 0.013775
# estimated using PhenomP final spin:
# (prec) final spin: 0.652305
# (prec) ringdown freq: 0.084914
# (prec) ringdown damp: 0.013642
# working: 38/40
# info:
# simname: q8a04t60D_dPm1
# filename: data/q8a04t60D_dPm1.h5
# eta: 0.09876538271585186
# X1: [0.16242918 0.3473319  0.1139076 ]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.988608
# assuming non-precessing:
# (non-prec) final spin: 0.390983
# (non-prec) ringdown freq: 0.070492
# (non-prec) ringdown damp: 0.014002
# estimated using PhenomP final spin:
# (prec) final spin: 0.498956
# (prec) ringdown freq: 0.074674
# (prec) ringdown damp: 0.013789
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))
# working: 39/40
# info:
# simname: q1a04t120_dP0_T_96_552
# filename: data/q1a04t120_dP0_T_96_552.h5
# eta: 0.25
# X1: [ 0.04721567  0.34626489 -0.19458573]
# X2: [0. 0. 0.]
# estimated remnant from fits:
# final mass: 0.95411
# assuming non-precessing:
# (non-prec) final spin: 0.656311
# (non-prec) ringdown freq: 0.085809
# (non-prec) ringdown damp: 0.013724
# estimated using PhenomP final spin:
# (prec) final spin: 0.663291
# (prec) ringdown freq: 0.086267
# (prec) ringdown damp: 0.013688
# /nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk/puck.py:29: RuntimeWarning: overflow encountered in exp
#   tout.append(1./(np.exp((t2-t1)/(t-t1)+(t2-t1)/(t-t2))+1))

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,5))
axes[0].plot(wfs[0].fd['freqs'], wfs[0].fd['psi4']['dphase'])
axes[1].plot(wfs[0].fd['freqs'], wfs[0].fd['strain']['dphase'])
# for ax in axes:
#     ax.set_xlim(*xlim)

axes[0].axvline(wfs[0].fring)
axes[1].axvline(wfs[0].fring)


axes[0].axvline(wfs[0].fring_non_prec, ls='--')
axes[1].axvline(wfs[0].fring_non_prec, ls='--')

# %%
# for wf in wfs:
#     wf.compute_fft(t12=[-1500, -800], t34=[100, 150], plot=False, take_pos_f=True, f_min=0.018, f_max=0.12)

# %%
plt.figure()
for wf in wfs:
    plt.plot(wf.fd['freqs'], wf.fd['psi4']['dphase']-wf.fd['psi4']['dphase'][0])

# %% [markdown]
# # save fit data

# %%
def save_data_being_fit(wfs, outdir="fit_data/phase"):
    
    print(f"making output dir: {outdir}")
    os.makedirs(f"{outdir}", exist_ok=True)  
    
    for wf in wfs:
        x = wf.fd['freqs']
        y = wf.fd['psi4']['dphase']-wf.fd['psi4']['dphase'][0]
        
        arr = np.array(list(zip(x, y)))
        
        np.save(os.path.join(outdir, wf.simname + ".npy"), arr)

# %%
# save_data_being_fit(wfs)

# %% [markdown]
# # fit

# %%
from lmfit import Model, Parameter, report_fit

# %%
def fit(wf):
    model = Model(dphimrd_func, independent_vars=['f'])
    x = wf.fd['freqs']
    y = wf.fd['psi4']['dphase']-wf.fd['psi4']['dphase'][0]

    f1 = wf.fring_non_prec*0.45
    f2 = wf.fring_non_prec*1.5
#     f2 = wf.fring_non_prec*1.2
#     f2 = 0.07
#     if 'q8' in wf.simname:
#         f2 = 0.09
    
    mask = (x>f1) & (x<f2)
    x = x[mask]
    y = y[mask]
    y = y
    
#     plt.figure()
#     plt.scatter(x, y)
#     plt.show()
#     plt.close()
    
    params = model.make_params()
    
    params['fdamp'].value = wf.fdamp_non_prec
    params['fdamp'].min = wf.fdamp_non_prec/5
    params['fdamp'].max = wf.fdamp_non_prec*5
    params['fdamp'].vary=False


    params['frd'].value = wf.fring_non_prec
#     params['frd'].min = wf.fring_non_prec-0.1
#     params['frd'].max = wf.fring_non_prec+0.2
    params['frd'].vary=False

    params['a1'].value = 400
    params['a1'].min = -100000
    params['a1'].max = 100000
    # params['a1'].vary=False

    params['a2'].value = 1
    params['a2'].min = -1000
    params['a2'].max = 1000
    # params['a2'].vary=False

    params['a3'].value = 100
    params['a3'].min = -100
    params['a3'].max = 100000
    # params['a3'].vary=False

    params['a4'].value = 100
    params['a4'].min = -1000
    params['a4'].max = 1000
    # params['a4'].vary=False

    params['a5'].value = 1
    params['a5'].min = -6
    params['a5'].max = 6
    # params['a5'].vary=False
    
    params['a6'].value = 1
    params['a6'].min = -10
    params['a6'].max = 10
    params['a6'].vary=False


    result = model.fit(y, params, f=x)
    
    report_fit(result.params)
    
    result.plot()
    plt.axvline(wf.fring, c='k', ls='--', label='fRD prediction (prec)')
    plt.axvline(wf.fring_non_prec, c='k', ls='-.', label='fRD prediction (non-prec)')
    plt.legend()
    plt.show()
    plt.close()
    
    return result

# %%
0.01362*1.2
# Out:
# 0.016344

# %%
[wf.simname for wf in wfs].index('q8a08t60Ditm45dr075_96_360')
# Out:
# 22

# %%
[wf.simname for wf in wfs].index('q8a08t150dP2_T_120_480')
# Out:
# 32

# %%
0.013624*0.930
# Out:
# 0.01267032

# %%
fit(wfs[22])
# Out:
# [[Variables]]
#     a1:    -2006.68211 +/- 7.14706887 (0.36%) (init = 400)
#     a2:     0.31397355 +/- 0.00327709 (1.04%) (init = 1)
#     a3:     94.4217419 +/- 4.01612916 (4.25%) (init = 100)
#     a4:    -1.33596844 +/- 0.00901799 (0.68%) (init = 100)
#     a5:     1.20696690 +/- 8.2616e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013624 (fixed)
#     frd:    0.078128 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.951
#     C(a1, a2) =  0.931
#     C(a1, a5) =  0.604
#     C(a3, a5) = -0.603
#     C(a2, a5) =  0.543
#     C(a1, a4) = -0.522
#     C(a3, a4) =  0.473
#     C(a4, a5) = -0.307
#     C(a2, a4) = -0.260
# <h2> Model</h2> Model(dphimrd_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>85</td><td></td></tr><tr><td># data points</td><td>2207</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 81688.9729</td><td></td></tr><tr><td>reduced chi-square</td><td> 37.0976262</td><td></td></tr><tr><td>Akaike info crit.</td><td> 7980.10576</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 8008.60271</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a1 </td><td> -2006.68211 </td><td>  7.14706887 </td><td> (0.36%) </td><td> 400 </td><td> -100000.000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a2 </td><td>  0.31397355 </td><td>  0.00327709 </td><td> (1.04%) </td><td> 1 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a3 </td><td>  94.4217419 </td><td>  4.01612916 </td><td> (4.25%) </td><td> 100 </td><td> -100.000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a4 </td><td> -1.33596844 </td><td>  0.00901799 </td><td> (0.68%) </td><td> 100 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a5 </td><td>  1.20696690 </td><td>  8.2616e-04 </td><td> (0.07%) </td><td> 1 </td><td> -6.00000000 </td><td>  6.00000000 </td><td> True </td></tr><tr><td> a6 </td><td>  1.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1 </td><td> -10.0000000 </td><td>  10.0000000 </td><td> False </td></tr><tr><td> fdamp </td><td>  0.01362400 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.013624 </td><td>  0.00272480 </td><td>  0.06812000 </td><td> False </td></tr><tr><td> frd </td><td>  0.07812800 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.078128 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a1</td><td>a3</td><td>-0.9980</td></tr><tr><td>a2</td><td>a3</td><td>-0.9506</td></tr><tr><td>a1</td><td>a2</td><td>0.9310</td></tr><tr><td>a1</td><td>a5</td><td>0.6044</td></tr><tr><td>a3</td><td>a5</td><td>-0.6030</td></tr><tr><td>a2</td><td>a5</td><td>0.5427</td></tr><tr><td>a1</td><td>a4</td><td>-0.5217</td></tr><tr><td>a3</td><td>a4</td><td>0.4732</td></tr><tr><td>a4</td><td>a5</td><td>-0.3069</td></tr><tr><td>a2</td><td>a4</td><td>-0.2598</td></tr></table>

# %%
fits = []
for i, wf in enumerate(wfs):
    print(f"working id: {i}")
    print(f"working: {wf.simname} \n")
    fits.append(fit(wf))
# Out:
# working id: 0
# working: q4a08t90dPm1D_T_96_384
#
# [[Variables]]
#     a1:    -888.674106 +/- 3.55688053 (0.40%) (init = 400)
#     a2:     0.28871706 +/- 0.00162039 (0.56%) (init = 1)
#     a3:    -43.4395848 +/- 2.01861844 (4.65%) (init = 100)
#     a4:    -1.20039993 +/- 0.00435918 (0.36%) (init = 100)
#     a5:     1.12984138 +/- 5.5096e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014009 (fixed)
#     frd:    0.074205 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.955
#     C(a1, a2) =  0.935
#     C(a1, a5) =  0.628
#     C(a3, a5) = -0.619
#     C(a2, a5) =  0.531
#     C(a4, a5) = -0.143
#     C(a1, a4) = -0.135
#     C(a2, a4) =  0.121
# working id: 1
# working: q2a04t30dPm2_T_96_408
#
# [[Variables]]
#     a1:    -1016.81749 +/- 2.03396896 (0.20%) (init = 400)
#     a2:     0.30408269 +/- 0.00127747 (0.42%) (init = 1)
#     a3:     3.58036977 +/- 1.20065661 (33.53%) (init = 100)
#     a4:    -1.20223051 +/- 0.00195181 (0.16%) (init = 100)
#     a5:     1.01326659 +/- 1.9815e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013334 (fixed)
#     frd:    0.090406 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.965
#     C(a1, a2) =  0.949
#     C(a1, a5) =  0.596
#     C(a3, a5) = -0.587
#     C(a2, a5) =  0.506
#     C(a2, a4) =  0.207
# working id: 2
# working: q8a08t90dP0_T_96_384
#
# [[Variables]]
#     a1:    -935.438086 +/- 8.64999510 (0.92%) (init = 400)
#     a2:     0.30114089 +/- 0.00293066 (0.97%) (init = 1)
#     a3:    -99.9999997 +/- 5.24534556 (5.25%) (init = 100)
#     a4:    -1.10989621 +/- 0.01119408 (1.01%) (init = 100)
#     a5:     1.19434061 +/- 0.00140932 (0.12%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.0141 (fixed)
#     frd:    0.067809 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) =  0.998
#     C(a2, a3) =  0.950
#     C(a1, a2) =  0.929
#     C(a1, a5) =  0.684
#     C(a3, a5) =  0.682
#     C(a2, a5) =  0.611
#     C(a1, a4) = -0.522
#     C(a3, a4) = -0.468
#     C(a4, a5) = -0.348
#     C(a2, a4) = -0.243
# working id: 3
# working: q4a04t90_T_96_360
#
# [[Variables]]
#     a1:    -904.608711 +/- 0.99990732 (0.11%) (init = 400)
#     a2:     0.22555024 +/- 4.9067e-04 (0.22%) (init = 1)
#     a3:     12.4253887 +/- 0.58357653 (4.70%) (init = 100)
#     a4:    -1.09416816 +/- 0.00117045 (0.11%) (init = 100)
#     a5:     1.02417588 +/- 1.5871e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014004 (fixed)
#     frd:    0.074329 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.972
#     C(a1, a2) =  0.960
#     C(a1, a5) =  0.576
#     C(a3, a5) = -0.563
#     C(a2, a4) =  0.560
#     C(a3, a4) = -0.475
#     C(a2, a5) =  0.474
#     C(a1, a4) =  0.433
#     C(a4, a5) =  0.148
# working id: 4
# working: q2_a10_a28_ph0_th120
#
# [[Variables]]
#     a1:    -672.895211 +/- 2.60649282 (0.39%) (init = 400)
#     a2:     0.20163882 +/- 0.00136830 (0.68%) (init = 1)
#     a3:     5.41586591 +/- 1.53207626 (28.29%) (init = 100)
#     a4:    -1.22513674 +/- 0.00307848 (0.25%) (init = 100)
#     a5:     1.02957795 +/- 3.6832e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014074 (fixed)
#     frd:    0.076875 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.971
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.567
#     C(a3, a5) = -0.554
#     C(a2, a4) =  0.536
#     C(a2, a5) =  0.466
#     C(a3, a4) = -0.446
#     C(a1, a4) =  0.403
#     C(a4, a5) =  0.130
# working id: 5
# working: q8a04t150dP9_T_96_360
#
# [[Variables]]
#     a1:    -646.197207 +/- 0.56571819 (0.09%) (init = 400)
#     a2:     0.17174475 +/- 1.8749e-04 (0.11%) (init = 1)
#     a3:    -8.98578879 +/- 0.31675439 (3.53%) (init = 100)
#     a4:    -1.04106313 +/- 6.6636e-04 (0.06%) (init = 100)
#     a5:     1.00322135 +/- 1.0540e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014258 (fixed)
#     frd:    0.061532 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.977
#     C(a1, a2) =  0.966
#     C(a2, a4) =  0.666
#     C(a1, a5) =  0.653
#     C(a3, a5) = -0.638
#     C(a3, a4) = -0.599
#     C(a1, a4) =  0.561
#     C(a2, a5) =  0.541
#     C(a4, a5) =  0.247
# working id: 6
# working: q4a08t60dPm3dRm250_T_96_384
#
# [[Variables]]
#     a1:    -1463.68222 +/- 3.65028564 (0.25%) (init = 400)
#     a2:     0.31482403 +/- 0.00199215 (0.63%) (init = 1)
#     a3:     71.8086932 +/- 2.10288987 (2.93%) (init = 100)
#     a4:    -1.32894529 +/- 0.00406784 (0.31%) (init = 100)
#     a5:     1.11688267 +/- 3.7264e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013421 (fixed)
#     frd:    0.084933 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.955
#     C(a1, a2) =  0.936
#     C(a1, a5) =  0.602
#     C(a3, a5) = -0.597
#     C(a2, a5) =  0.526
#     C(a1, a4) = -0.343
#     C(a3, a4) =  0.290
#     C(a4, a5) = -0.233
# working id: 7
# working: q2_a10_a28_ph0_th30
#
# [[Variables]]
#     a1:    -1485.00469 +/- 1.40058979 (0.09%) (init = 400)
#     a2:     0.31078488 +/- 8.3227e-04 (0.27%) (init = 1)
#     a3:     121.228528 +/- 0.80813974 (0.67%) (init = 100)
#     a4:    -1.11064130 +/- 0.00115272 (0.10%) (init = 100)
#     a5:     1.02814161 +/- 6.8427e-05 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012453 (fixed)
#     frd:    0.101833 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.972
#     C(a1, a2) =  0.962
#     C(a1, a4) = -0.748
#     C(a3, a4) =  0.724
#     C(a3, a5) = -0.615
#     C(a1, a5) =  0.613
#     C(a2, a5) =  0.595
#     C(a2, a4) = -0.580
#     C(a4, a5) = -0.420
# working id: 8
# working: q2a04t120_T_96_408
#
# [[Variables]]
#     a1:    -663.764340 +/- 2.49916865 (0.38%) (init = 400)
#     a2:     0.24355556 +/- 0.00144378 (0.59%) (init = 1)
#     a3:    -32.0518307 +/- 1.49034159 (4.65%) (init = 100)
#     a4:    -1.15332908 +/- 0.00288187 (0.25%) (init = 100)
#     a5:     0.99683835 +/- 3.3552e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013902 (fixed)
#     frd:    0.080665 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.964
#     C(a2, a4) =  0.607
#     C(a3, a4) = -0.544
#     C(a1, a5) =  0.529
#     C(a3, a5) = -0.517
#     C(a1, a4) =  0.508
#     C(a2, a5) =  0.433
#     C(a4, a5) =  0.178
# working id: 9
# working: q4a04t60dPm1.5D_T_96_360
#
# [[Variables]]
#     a1:    -1052.39855 +/- 1.40475327 (0.13%) (init = 400)
#     a2:     0.27841342 +/- 7.8925e-04 (0.28%) (init = 1)
#     a3:    -6.26804342 +/- 0.83232145 (13.28%) (init = 100)
#     a4:    -1.16521653 +/- 0.00163110 (0.14%) (init = 100)
#     a5:     1.02732406 +/- 1.9696e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013757 (fixed)
#     frd:    0.079372 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.971
#     C(a1, a2) =  0.959
#     C(a1, a5) =  0.541
#     C(a2, a4) =  0.533
#     C(a3, a5) = -0.529
#     C(a3, a4) = -0.447
#     C(a2, a5) =  0.444
#     C(a1, a4) =  0.406
#     C(a4, a5) =  0.127
# working id: 10
# working: q2a04t150_T_96_408
#
# [[Variables]]
#     a1:    -648.153704 +/- 2.69408798 (0.42%) (init = 400)
#     a2:     0.20793147 +/- 0.00149874 (0.72%) (init = 1)
#     a3:    -8.85362632 +/- 1.60463388 (18.12%) (init = 100)
#     a4:    -1.12673368 +/- 0.00315555 (0.28%) (init = 100)
#     a5:     0.97916579 +/- 3.6694e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013982 (fixed)
#     frd:    0.078973 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.978
#     C(a1, a2) =  0.968
#     C(a2, a4) =  0.667
#     C(a3, a4) = -0.623
#     C(a1, a4) =  0.593
#     C(a1, a5) =  0.519
#     C(a3, a5) = -0.507
#     C(a2, a5) =  0.424
#     C(a4, a5) =  0.222
# working id: 11
# working: q4a08t30dPm5p5dRm47_T_96_360
#
# [[Variables]]
#     a1:    -1833.92468 +/- 4.71751644 (0.26%) (init = 400)
#     a2:     0.39442208 +/- 0.00248733 (0.63%) (init = 1)
#     a3:     80.5051105 +/- 2.68456531 (3.33%) (init = 100)
#     a4:    -1.39006540 +/- 0.00473276 (0.34%) (init = 100)
#     a5:     1.11987437 +/- 2.6596e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012889 (fixed)
#     frd:    0.092133 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.954
#     C(a1, a4) = -0.736
#     C(a3, a4) =  0.708
#     C(a3, a5) = -0.592
#     C(a1, a5) =  0.590
#     C(a2, a5) =  0.569
#     C(a2, a4) = -0.550
#     C(a4, a5) = -0.394
# working id: 12
# working: q1a08t30dPm25_T_96_408
#
# [[Variables]]
#     a1:    -1146.92196 +/- 2.20033214 (0.19%) (init = 400)
#     a2:     0.29943567 +/- 0.00140108 (0.47%) (init = 1)
#     a3:     59.7852223 +/- 1.28772083 (2.15%) (init = 100)
#     a4:    -1.14403801 +/- 0.00188829 (0.17%) (init = 100)
#     a5:     1.00193081 +/- 1.6309e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012963 (fixed)
#     frd:    0.097649 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.635
#     C(a3, a5) = -0.630
#     C(a2, a5) =  0.565
#     C(a1, a4) = -0.371
#     C(a3, a4) =  0.325
#     C(a4, a5) = -0.271
#     C(a2, a4) = -0.131
# working id: 13
# working: q2_a10_a28_ph0_th60
#
# [[Variables]]
#     a1:    -1196.86251 +/- 3.23440120 (0.27%) (init = 400)
#     a2:     0.26506933 +/- 0.00183008 (0.69%) (init = 1)
#     a3:     75.2806974 +/- 1.86545095 (2.48%) (init = 100)
#     a4:    -1.32473605 +/- 0.00333889 (0.25%) (init = 100)
#     a5:     1.08335080 +/- 2.7359e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013379 (fixed)
#     frd:    0.089731 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.958
#     C(a1, a2) =  0.941
#     C(a1, a5) =  0.622
#     C(a3, a5) = -0.618
#     C(a2, a5) =  0.555
#     C(a1, a4) = -0.439
#     C(a3, a4) =  0.392
#     C(a4, a5) = -0.288
#     C(a2, a4) = -0.188
# working id: 14
# working: q8a08t120dP2_r03_T_96_360
#
# [[Variables]]
#     a1:    -531.561632 +/- 13.6279603 (2.56%) (init = 400)
#     a2:     0.19018187 +/- 0.00640763 (3.37%) (init = 1)
#     a3:    -68.8381121 +/- 8.00083354 (11.62%) (init = 100)
#     a4:    -1.01713053 +/- 0.01594146 (1.57%) (init = 100)
#     a5:     0.92970102 +/- 0.00186686 (0.20%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013882 (fixed)
#     frd:    0.073231 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.983
#     C(a1, a2) =  0.977
#     C(a2, a4) =  0.777
#     C(a3, a4) = -0.763
#     C(a1, a4) =  0.744
#     C(a1, a5) =  0.500
#     C(a3, a5) = -0.488
#     C(a2, a5) =  0.405
#     C(a4, a5) =  0.304
# working id: 15
# working: q2a04t60dPm1_T_96_408
#
# [[Variables]]
#     a1:    -951.322231 +/- 1.87540971 (0.20%) (init = 400)
#     a2:     0.27059089 +/- 0.00114180 (0.42%) (init = 1)
#     a3:     12.6919336 +/- 1.10938359 (8.74%) (init = 100)
#     a4:    -1.19628990 +/- 0.00194558 (0.16%) (init = 100)
#     a5:     1.02336485 +/- 2.1418e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013592 (fixed)
#     frd:    0.086343 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.952
#     C(a1, a5) =  0.578
#     C(a3, a5) = -0.568
#     C(a2, a5) =  0.484
#     C(a2, a4) =  0.336
#     C(a3, a4) = -0.196
#     C(a1, a4) =  0.147
# working id: 16
# working: q4a08t120dP1_T_96_360
#
# [[Variables]]
#     a1:    -524.930108 +/- 2.76490863 (0.53%) (init = 400)
#     a2:     0.21518554 +/- 0.00108468 (0.50%) (init = 1)
#     a3:    -73.3751755 +/- 1.55566821 (2.12%) (init = 100)
#     a4:    -1.22546298 +/- 0.00330795 (0.27%) (init = 100)
#     a5:     1.08040606 +/- 4.5579e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014242 (fixed)
#     frd:    0.067665 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.946
#     C(a1, a5) =  0.656
#     C(a3, a5) = -0.644
#     C(a2, a5) =  0.545
#     C(a2, a4) =  0.359
#     C(a3, a4) = -0.206
#     C(a1, a4) =  0.148
# working id: 17
# working: q1a08t150dP0_T_96_408
#
# [[Variables]]
#     a1:    -500.719641 +/- 8.22110037 (1.64%) (init = 400)
#     a2:     0.25473285 +/- 0.00490555 (1.93%) (init = 1)
#     a3:    -70.8135960 +/- 4.91075841 (6.93%) (init = 100)
#     a4:    -1.21650060 +/- 0.00905310 (0.74%) (init = 100)
#     a5:     0.98683623 +/- 9.7841e-04 (0.10%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013874 (fixed)
#     frd:    0.082917 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.964
#     C(a2, a4) =  0.587
#     C(a1, a5) =  0.538
#     C(a3, a5) = -0.526
#     C(a3, a4) = -0.517
#     C(a1, a4) =  0.481
#     C(a2, a5) =  0.443
#     C(a4, a5) =  0.163
# working id: 18
# working: q1a08t60dPm1.5_T_96_408
#
# [[Variables]]
#     a1:    -962.762167 +/- 1.76686433 (0.18%) (init = 400)
#     a2:     0.31536494 +/- 0.00111950 (0.35%) (init = 1)
#     a3:     2.76401308 +/- 1.03928472 (37.60%) (init = 100)
#     a4:    -1.16420951 +/- 0.00162779 (0.14%) (init = 100)
#     a5:     1.00971093 +/- 1.5958e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013269 (fixed)
#     frd:    0.093299 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.616
#     C(a3, a5) = -0.608
#     C(a2, a5) =  0.531
#     C(a4, a5) = -0.164
#     C(a1, a4) = -0.157
#     C(a3, a4) =  0.107
# working id: 19
# working: q8a08t30dPm9.35_r0.5_T_96_360
#
# [[Variables]]
#     a1:    -2778.07440 +/- 3.89993127 (0.14%) (init = 400)
#     a2:     0.45704842 +/- 0.00223567 (0.49%) (init = 1)
#     a3:     133.808148 +/- 2.24562983 (1.68%) (init = 100)
#     a4:    -1.23071764 +/- 0.00353025 (0.29%) (init = 100)
#     a5:     1.07030041 +/- 2.4612e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.012361 (fixed)
#     frd:    0.094354 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.963
#     C(a1, a2) =  0.949
#     C(a1, a4) = -0.603
#     C(a1, a5) =  0.603
#     C(a3, a5) = -0.602
#     C(a3, a4) =  0.567
#     C(a2, a5) =  0.560
#     C(a2, a4) = -0.385
#     C(a4, a5) = -0.350
# working id: 20
# working: q8a04t90dP0_T_96_360
#
# [[Variables]]
#     a1:    -939.564957 +/- 2.05004531 (0.22%) (init = 400)
#     a2:     0.25122796 +/- 8.1819e-04 (0.33%) (init = 1)
#     a3:    -42.1174377 +/- 1.16186385 (2.76%) (init = 100)
#     a4:    -1.17792972 +/- 0.00240971 (0.20%) (init = 100)
#     a5:     1.05406923 +/- 3.3842e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014105 (fixed)
#     frd:    0.06767 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.968
#     C(a1, a2) =  0.953
#     C(a1, a5) =  0.638
#     C(a3, a5) = -0.625
#     C(a2, a5) =  0.527
#     C(a2, a4) =  0.470
#     C(a3, a4) = -0.349
#     C(a1, a4) =  0.297
# working id: 21
# working: q1a04t90_dP0_T_96_552
#
# [[Variables]]
#     a1:    -765.610542 +/- 2.99876736 (0.39%) (init = 400)
#     a2:     0.27270468 +/- 0.00187260 (0.69%) (init = 1)
#     a3:    -18.4313009 +/- 1.77937908 (9.65%) (init = 100)
#     a4:    -1.19610039 +/- 0.00300280 (0.25%) (init = 100)
#     a5:     1.00473699 +/- 3.2268e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013596 (fixed)
#     frd:    0.088083 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.968
#     C(a1, a2) =  0.954
#     C(a1, a5) =  0.581
#     C(a3, a5) = -0.570
#     C(a2, a5) =  0.487
#     C(a2, a4) =  0.355
#     C(a3, a4) = -0.221
#     C(a1, a4) =  0.172
# working id: 22
# working: q8a08t60Ditm45dr075_96_360
#
# [[Variables]]
#     a1:    -2006.68211 +/- 7.14706887 (0.36%) (init = 400)
#     a2:     0.31397355 +/- 0.00327709 (1.04%) (init = 1)
#     a3:     94.4217419 +/- 4.01612916 (4.25%) (init = 100)
#     a4:    -1.33596844 +/- 0.00901799 (0.68%) (init = 100)
#     a5:     1.20696690 +/- 8.2616e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013624 (fixed)
#     frd:    0.078128 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.951
#     C(a1, a2) =  0.931
#     C(a1, a5) =  0.604
#     C(a3, a5) = -0.603
#     C(a2, a5) =  0.543
#     C(a1, a4) = -0.522
#     C(a3, a4) =  0.473
#     C(a4, a5) = -0.307
#     C(a2, a4) = -0.260
# working id: 23
# working: q8a04t30dPm3_T_96_360
#
# [[Variables]]
#     a1:    -1567.16758 +/- 1.43651407 (0.09%) (init = 400)
#     a2:     0.34590468 +/- 5.8411e-04 (0.17%) (init = 1)
#     a3:    -18.6227313 +/- 0.80544662 (4.33%) (init = 100)
#     a4:    -1.07189348 +/- 0.00174016 (0.16%) (init = 100)
#     a5:     1.11843194 +/- 2.6033e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014024 (fixed)
#     frd:    0.069932 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.957
#     C(a1, a2) =  0.937
#     C(a1, a5) =  0.651
#     C(a3, a5) = -0.641
#     C(a2, a5) =  0.548
#     C(a2, a4) =  0.175
#     C(a4, a5) = -0.120
# working id: 24
# working: q8a04t120dPp1_T_96_360
#
# [[Variables]]
#     a1:    -686.948711 +/- 1.41236976 (0.21%) (init = 400)
#     a2:     0.21820088 +/- 5.3093e-04 (0.24%) (init = 1)
#     a3:    -52.6156286 +/- 0.80057309 (1.52%) (init = 100)
#     a4:    -1.09394388 +/- 0.00165427 (0.15%) (init = 100)
#     a5:     1.01475890 +/- 2.4363e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014174 (fixed)
#     frd:    0.065373 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.974
#     C(a1, a2) =  0.963
#     C(a1, a5) =  0.632
#     C(a3, a5) = -0.618
#     C(a2, a4) =  0.617
#     C(a3, a4) = -0.539
#     C(a2, a5) =  0.522
#     C(a1, a4) =  0.498
#     C(a4, a5) =  0.200
# working id: 25
# working: q4a04t150_T_96_360
#
# [[Variables]]
#     a1:    -652.316535 +/- 0.64050179 (0.10%) (init = 400)
#     a2:     0.17858582 +/- 2.5846e-04 (0.14%) (init = 1)
#     a3:     0.62959289 +/- 0.36645627 (58.21%) (init = 100)
#     a4:    -1.09955150 +/- 7.5477e-04 (0.07%) (init = 100)
#     a5:     1.00821651 +/- 1.0697e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014244 (fixed)
#     frd:    0.067602 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.964
#     C(a2, a4) =  0.632
#     C(a1, a5) =  0.616
#     C(a3, a5) = -0.601
#     C(a3, a4) = -0.561
#     C(a1, a4) =  0.522
#     C(a2, a5) =  0.507
#     C(a4, a5) =  0.210
# working id: 26
# working: q4a04t30_T_96_360
#
# [[Variables]]
#     a1:    -1223.60165 +/- 0.75417625 (0.06%) (init = 400)
#     a2:     0.30048418 +/- 4.1044e-04 (0.14%) (init = 1)
#     a3:     10.4782626 +/- 0.44212418 (4.22%) (init = 100)
#     a4:    -1.16374660 +/- 8.8893e-04 (0.08%) (init = 100)
#     a5:     1.07164952 +/- 1.1226e-04 (0.01%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01379 (fixed)
#     frd:    0.078768 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.964
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.569
#     C(a3, a5) = -0.557
#     C(a2, a5) =  0.470
#     C(a2, a4) =  0.380
#     C(a3, a4) = -0.248
#     C(a1, a4) =  0.197
# working id: 27
# working: q1a04t60_dPm1_T_96_552
#
# [[Variables]]
#     a1:    -866.218362 +/- 2.54219443 (0.29%) (init = 400)
#     a2:     0.28275376 +/- 0.00161614 (0.57%) (init = 1)
#     a3:    -1.54992378 +/- 1.50543325 (97.13%) (init = 100)
#     a4:    -1.18311085 +/- 0.00242744 (0.21%) (init = 100)
#     a5:     1.00150888 +/- 2.5251e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013442 (fixed)
#     frd:    0.090625 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.967
#     C(a1, a2) =  0.952
#     C(a1, a5) =  0.595
#     C(a3, a5) = -0.585
#     C(a2, a5) =  0.503
#     C(a2, a4) =  0.263
#     C(a3, a4) = -0.109
# working id: 28
# working: q2_a10_a28_ph0_th150
#
# [[Variables]]
#     a1:    -593.674103 +/- 4.13460168 (0.70%) (init = 400)
#     a2:     0.15923806 +/- 0.00192304 (1.21%) (init = 1)
#     a3:     20.0992107 +/- 2.40600059 (11.97%) (init = 100)
#     a4:    -1.09262791 +/- 0.00489273 (0.45%) (init = 100)
#     a5:     1.00417483 +/- 6.6083e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014242 (fixed)
#     frd:    0.072367 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.975
#     C(a1, a2) =  0.965
#     C(a2, a4) =  0.629
#     C(a1, a5) =  0.583
#     C(a3, a5) = -0.569
#     C(a3, a4) = -0.563
#     C(a1, a4) =  0.526
#     C(a2, a5) =  0.479
#     C(a4, a5) =  0.203
# working id: 29
# working: q1a04t150_dP0_T_96_552
#
# [[Variables]]
#     a1:    -621.696698 +/- 4.43234396 (0.71%) (init = 400)
#     a2:     0.25743112 +/- 0.00267016 (1.04%) (init = 1)
#     a3:    -44.3178788 +/- 2.63682552 (5.95%) (init = 100)
#     a4:    -1.22008289 +/- 0.00478890 (0.39%) (init = 100)
#     a5:     1.00646412 +/- 5.2749e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013811 (fixed)
#     frd:    0.084162 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.971
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.558
#     C(a3, a5) = -0.547
#     C(a2, a4) =  0.486
#     C(a2, a5) =  0.462
#     C(a3, a4) = -0.386
#     C(a1, a4) =  0.343
# working id: 30
# working: q1a04t30_dPm2_T_96_552
#
# [[Variables]]
#     a1:    -948.186968 +/- 2.89492360 (0.31%) (init = 400)
#     a2:     0.28096109 +/- 0.00186105 (0.66%) (init = 1)
#     a3:     18.6628362 +/- 1.71153657 (9.17%) (init = 100)
#     a4:    -1.17743820 +/- 0.00266620 (0.23%) (init = 100)
#     a5:     0.99810236 +/- 2.6716e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013311 (fixed)
#     frd:    0.092657 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.965
#     C(a1, a2) =  0.950
#     C(a1, a5) =  0.605
#     C(a3, a5) = -0.596
#     C(a2, a5) =  0.516
#     C(a2, a4) =  0.185
#     C(a4, a5) = -0.103
# working id: 31
# working: q1a08t120dP0_T_96_408
#
# [[Variables]]
#     a1:    -615.940054 +/- 3.54496709 (0.58%) (init = 400)
#     a2:     0.26780619 +/- 0.00211738 (0.79%) (init = 1)
#     a3:    -51.2740419 +/- 2.10547424 (4.11%) (init = 100)
#     a4:    -1.22785190 +/- 0.00388021 (0.32%) (init = 100)
#     a5:     1.01674140 +/- 4.3093e-04 (0.04%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01384 (fixed)
#     frd:    0.083594 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.970
#     C(a1, a2) =  0.957
#     C(a1, a5) =  0.561
#     C(a3, a5) = -0.549
#     C(a2, a4) =  0.467
#     C(a2, a5) =  0.464
#     C(a3, a4) = -0.361
#     C(a1, a4) =  0.316
# working id: 32
# working: q8a08t150dP2_T_120_480
#
# [[Variables]]
#     a1:    -705.145943 +/- 6.41744176 (0.91%) (init = 400)
#     a2:     0.03665758 +/- 0.00285482 (7.79%) (init = 1)
#     a3:     140.990565 +/- 3.76839104 (2.67%) (init = 100)
#     a4:    -1.29384619 +/- 0.00811603 (0.63%) (init = 100)
#     a5:     0.75891775 +/- 5.1668e-04 (0.07%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013803 (fixed)
#     frd:    0.074863 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -1.000
#     C(a2, a3) = -0.983
#     C(a1, a2) =  0.979
#     C(a3, a4) = -0.886
#     C(a1, a4) =  0.882
#     C(a2, a4) =  0.833
#     C(a2, a5) = -0.173
# working id: 33
# working: q1a08t90dPm1_T_96_408
#
# [[Variables]]
#     a1:    -848.938397 +/- 1.89817867 (0.22%) (init = 400)
#     a2:     0.24528940 +/- 0.00117506 (0.48%) (init = 1)
#     a3:     15.5380263 +/- 1.12294901 (7.23%) (init = 100)
#     a4:    -1.17251065 +/- 0.00191294 (0.16%) (init = 100)
#     a5:     1.01558811 +/- 2.0984e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013596 (fixed)
#     frd:    0.088082 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.966
#     C(a1, a2) =  0.951
#     C(a1, a5) =  0.588
#     C(a3, a5) = -0.577
#     C(a2, a5) =  0.494
#     C(a2, a4) =  0.301
#     C(a3, a4) = -0.154
#     C(a1, a4) =  0.103
# working id: 34
# working: q4a08t150_T_96_360
#
# [[Variables]]
#     a1:    -468.463742 +/- 2.78945078 (0.60%) (init = 400)
#     a2:     0.15679982 +/- 0.00105032 (0.67%) (init = 1)
#     a3:    -16.5950091 +/- 1.58861284 (9.57%) (init = 100)
#     a4:    -1.06180392 +/- 0.00330772 (0.31%) (init = 100)
#     a5:     0.98700410 +/- 4.7384e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014299 (fixed)
#     frd:    0.065392 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.999
#     C(a2, a3) = -0.978
#     C(a1, a2) =  0.969
#     C(a2, a4) =  0.698
#     C(a3, a4) = -0.646
#     C(a1, a5) =  0.616
#     C(a1, a4) =  0.613
#     C(a3, a5) = -0.602
#     C(a2, a5) =  0.509
#     C(a4, a5) =  0.270
# working id: 35
# working: q2_a10_a28_ph0_th90
#
# [[Variables]]
#     a1:    -1039.92400 +/- 1.67901182 (0.16%) (init = 400)
#     a2:     0.15986307 +/- 9.7421e-04 (0.61%) (init = 1)
#     a3:     122.589271 +/- 0.98794781 (0.81%) (init = 100)
#     a4:    -1.24007498 +/- 0.00188227 (0.15%) (init = 100)
#     a5:     1.05782266 +/- 2.1134e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013777 (fixed)
#     frd:    0.083085 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.964
#     C(a1, a2) =  0.947
#     C(a1, a5) =  0.578
#     C(a3, a5) = -0.567
#     C(a2, a5) =  0.481
#     C(a2, a4) =  0.313
#     C(a3, a4) = -0.166
#     C(a1, a4) =  0.114
# working id: 36
# working: q4a04t120dP0D_T_96_360
#
# [[Variables]]
#     a1:    -722.214618 +/- 1.14300143 (0.16%) (init = 400)
#     a2:     0.20494508 +/- 5.0413e-04 (0.25%) (init = 1)
#     a3:    -10.4584250 +/- 0.65923457 (6.30%) (init = 100)
#     a4:    -1.15501205 +/- 0.00134319 (0.12%) (init = 100)
#     a5:     1.02172238 +/- 1.7941e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.01415 (fixed)
#     frd:    0.07059 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.973
#     C(a1, a2) =  0.961
#     C(a1, a5) =  0.602
#     C(a3, a5) = -0.589
#     C(a2, a4) =  0.580
#     C(a3, a4) = -0.497
#     C(a2, a5) =  0.496
#     C(a1, a4) =  0.455
#     C(a4, a5) =  0.166
# working id: 37
# working: q2a04t90dPm1_T_96_408
#
# [[Variables]]
#     a1:    -828.071135 +/- 2.06331938 (0.25%) (init = 400)
#     a2:     0.23903822 +/- 0.00122572 (0.51%) (init = 1)
#     a3:     5.88853468 +/- 1.22587510 (20.82%) (init = 100)
#     a4:    -1.19123247 +/- 0.00226750 (0.19%) (init = 100)
#     a5:     1.01579183 +/- 2.5928e-04 (0.03%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013775 (fixed)
#     frd:    0.083133 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.970
#     C(a1, a2) =  0.958
#     C(a1, a5) =  0.555
#     C(a3, a5) = -0.543
#     C(a2, a4) =  0.482
#     C(a2, a5) =  0.459
#     C(a3, a4) = -0.381
#     C(a1, a4) =  0.337
# working id: 38
# working: q8a04t60D_dPm1
#
# [[Variables]]
#     a1:    -1283.29249 +/- 1.52872929 (0.12%) (init = 400)
#     a2:     0.29157308 +/- 6.5990e-04 (0.23%) (init = 1)
#     a3:    -25.6955205 +/- 0.87166386 (3.39%) (init = 100)
#     a4:    -1.11453227 +/- 0.00180098 (0.16%) (init = 100)
#     a5:     1.07126063 +/- 2.6052e-04 (0.02%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.014002 (fixed)
#     frd:    0.070492 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.965
#     C(a1, a2) =  0.948
#     C(a1, a5) =  0.626
#     C(a3, a5) = -0.613
#     C(a2, a5) =  0.518
#     C(a2, a4) =  0.396
#     C(a3, a4) = -0.258
#     C(a1, a4) =  0.203
# working id: 39
# working: q1a04t120_dP0_T_96_552
#
# [[Variables]]
#     a1:    -697.049924 +/- 4.09353979 (0.59%) (init = 400)
#     a2:     0.25616306 +/- 0.00250747 (0.98%) (init = 1)
#     a3:    -24.2202631 +/- 2.43328411 (10.05%) (init = 100)
#     a4:    -1.21596026 +/- 0.00428055 (0.35%) (init = 100)
#     a5:     1.00528390 +/- 4.6560e-04 (0.05%) (init = 1)
#     a6:     1 (fixed)
#     fdamp:  0.013724 (fixed)
#     frd:    0.085809 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a1, a3) = -0.998
#     C(a2, a3) = -0.970
#     C(a1, a2) =  0.957
#     C(a1, a5) =  0.568
#     C(a3, a5) = -0.556
#     C(a2, a5) =  0.472
#     C(a2, a4) =  0.437
#     C(a3, a4) = -0.323
#     C(a1, a4) =  0.277

# %%
fits[0]
# Out:
# <h2> Model</h2> Model(dphimrd_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>2338</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 26895.7581</td><td></td></tr><tr><td>reduced chi-square</td><td> 11.5284004</td><td></td></tr><tr><td>Akaike info crit.</td><td> 5720.96882</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 5749.75407</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a1 </td><td> -888.674106 </td><td>  3.55688053 </td><td> (0.40%) </td><td> 400 </td><td> -100000.000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a2 </td><td>  0.28871706 </td><td>  0.00162039 </td><td> (0.56%) </td><td> 1 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a3 </td><td> -43.4395848 </td><td>  2.01861844 </td><td> (4.65%) </td><td> 100 </td><td> -100.000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> a4 </td><td> -1.20039993 </td><td>  0.00435918 </td><td> (0.36%) </td><td> 100 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> a5 </td><td>  1.12984138 </td><td>  5.5096e-04 </td><td> (0.05%) </td><td> 1 </td><td> -6.00000000 </td><td>  6.00000000 </td><td> True </td></tr><tr><td> a6 </td><td>  1.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1 </td><td> -10.0000000 </td><td>  10.0000000 </td><td> False </td></tr><tr><td> fdamp </td><td>  0.01400900 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.014009 </td><td>  0.00280180 </td><td>  0.07004500 </td><td> False </td></tr><tr><td> frd </td><td>  0.07420500 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.074205 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a1</td><td>a3</td><td>-0.9976</td></tr><tr><td>a2</td><td>a3</td><td>-0.9551</td></tr><tr><td>a1</td><td>a2</td><td>0.9348</td></tr><tr><td>a1</td><td>a5</td><td>0.6279</td></tr><tr><td>a3</td><td>a5</td><td>-0.6194</td></tr><tr><td>a2</td><td>a5</td><td>0.5307</td></tr><tr><td>a4</td><td>a5</td><td>-0.1427</td></tr><tr><td>a1</td><td>a4</td><td>-0.1352</td></tr><tr><td>a2</td><td>a4</td><td>0.1212</td></tr></table>

# %%
fits[0].params['a1'].value
# Out:
# -888.6741059834603

# %%
wfs[0].eta
# Out:
# 0.16000039999600005

# %%
wfs[0].X1
# Out:
# array([-7.27303692e-04,  7.99961251e-01, -5.49319079e-03])

# %%
def cart_to_polar(x, y, z):
    """
    cartesian to spherical polar transformation
    returns: r, theta, phi
    """
    hxy = np.hypot(x, y)
    r = np.hypot(hxy, z)
    theta = np.arctan2(hxy, z)
    phi = np.arctan2(y, x) % (2*np.pi)
    return r, theta, phi

# %%
psf_names = []

psf_coords = []
for wf in wfs:
    
    psf_names.append(wf.simname)
    
    r, theta, phi = cart_to_polar(*wf.X1)
#     psf_coords.append([wf.eta, r, theta, phi])
#     psf_coords.append([wf.eta, r])
#     psf_coords.append([wf.eta, theta])
#     psf_coords.append([wf.eta, np.cos(theta)])
    psf_coords.append([wf.eta, np.cos(theta), r])
#     psf_coords.append([wf.eta, phi])
#     psf_coords.append([wf.eta, wf.X1[0]])
#     psf_coords.append([wf.eta, wf.X1[1]])
#     psf_coords.append([wf.eta, wf.X1[2]])
psf_coords = np.array(psf_coords)

# %%
psf_coords
# Out:
# array([[ 1.60000400e-01, -6.86665637e-03,  7.99980442e-01],
#        [ 2.22222778e-01,  8.05327355e-01,  3.99991541e-01],
#        [ 9.87654444e-02,  6.11707978e-03,  7.99985695e-01],
#        [ 1.60000200e-01, -1.80827695e-04,  3.99994224e-01],
#        [ 2.22223111e-01, -4.52626969e-01,  7.99977434e-01],
#        [ 9.87653827e-02, -7.96287068e-01,  3.99997142e-01],
#        [ 1.60000400e-01,  4.65013824e-01,  7.99979739e-01],
#        [ 2.22223111e-01,  8.62400521e-01,  7.99976827e-01],
#        [ 2.22222778e-01, -3.30999947e-01,  3.99992162e-01],
#        [ 1.60000200e-01,  4.92715221e-01,  3.99994694e-01],
#        [ 2.22222778e-01, -5.76191041e-01,  3.99992545e-01],
#        [ 1.60000400e-01,  6.88431589e-01,  7.99980060e-01],
#        [ 2.50000000e-01,  8.35069297e-01,  7.99971874e-01],
#        [ 2.22223111e-01,  3.69548480e-01,  7.99977507e-01],
#        [ 9.87654444e-02,  2.64786048e-01,  7.99985714e-01],
#        [ 2.22222778e-01,  3.81258462e-01,  3.99991916e-01],
#        [ 1.60000400e-01, -4.27339816e-01,  7.99980052e-01],
#        [ 2.50000000e-01, -5.82720129e-01,  7.99971024e-01],
#        [ 2.50000000e-01,  4.88244437e-01,  7.99970485e-01],
#        [ 9.87654444e-02,  8.62409231e-01,  7.99985678e-01],
#        [ 9.87653827e-02, -2.89005061e-03,  3.99997327e-01],
#        [ 2.50000000e-01, -7.03956819e-04,  3.99990503e-01],
#        [ 9.87662099e-02,  4.49904477e-01,  7.99988818e-01],
#        [ 9.87653827e-02,  2.30806812e-01,  3.99997472e-01],
#        [ 9.87653827e-02, -2.69286667e-01,  3.99997271e-01],
#        [ 1.60000200e-01, -8.64292215e-01,  3.99995349e-01],
#        [ 1.60000200e-01,  4.39109243e-01,  3.99995120e-01],
#        [ 2.50000000e-01,  4.97416933e-01,  3.99990454e-01],
#        [ 2.22223111e-01, -8.60616973e-01,  7.99977219e-01],
#        [ 2.50000000e-01, -8.64231942e-01,  3.99990427e-01],
#        [ 2.50000000e-01,  8.65455397e-01,  3.99990217e-01],
#        [ 2.50000000e-01, -4.99958686e-01,  7.99971703e-01],
#        [ 9.87654444e-02,  3.30834258e-01,  7.99985684e-01],
#        [ 2.50000000e-01, -5.14869609e-04,  7.99971808e-01],
#        [ 1.60002280e-01, -6.09487866e-01,  7.99982545e-01],
#        [ 2.22223111e-01, -4.04330143e-03,  7.99978555e-01],
#        [ 1.60000200e-01, -4.45222104e-01,  3.99995496e-01],
#        [ 2.22222778e-01, -2.02830653e-03,  3.99991481e-01],
#        [ 9.87653827e-02,  2.84771123e-01,  3.99997032e-01],
#        [ 2.50000000e-01, -4.86476032e-01,  3.99990374e-01]])

# %%
params = fits[0].params

# %%
psf_data={}
for k in params.keys():
    if fits[0].params[k].vary:
        v = np.array([fits[i].params[k].value for i in range(len(fits))])
        psf_data.update({k:v})

# %%
psf_data.keys()
# Out:
# dict_keys(['a1', 'a2', 'a3', 'a4', 'a5'])

# %%
psf_data['a1']
# Out:
# array([ -888.67410598, -1016.81748595,  -935.43808611,  -904.60871116,
#         -672.89521056,  -646.1972066 , -1463.68222052, -1485.00468639,
#         -663.76433963, -1052.39854509,  -648.15370371, -1833.92468375,
#        -1146.92195877, -1196.86251469,  -531.56163243,  -951.3222315 ,
#         -524.93010803,  -500.71964096,  -962.76216726, -2778.07440309,
#         -939.56495744,  -765.61054163, -2006.68211147, -1567.16758095,
#         -686.94871114,  -652.3165349 , -1223.60164894,  -866.21836164,
#         -593.67410311,  -621.69669787,  -948.18696835,  -615.94005437,
#         -705.14594318,  -848.93839714,  -468.46374166, -1039.92399934,
#         -722.21461827,  -828.07113535, -1283.29248958,  -697.04992412])

# %%
psf_coords[:,0]
# Out:
# array([0.1600004 , 0.22222278, 0.09876544, 0.1600002 , 0.22222311,
#        0.09876538, 0.1600004 , 0.22222311, 0.22222278, 0.1600002 ,
#        0.22222278, 0.1600004 , 0.25      , 0.22222311, 0.09876544,
#        0.22222278, 0.1600004 , 0.25      , 0.25      , 0.09876544,
#        0.09876538, 0.25      , 0.09876621, 0.09876538, 0.09876538,
#        0.1600002 , 0.1600002 , 0.25      , 0.22222311, 0.25      ,
#        0.25      , 0.25      , 0.09876544, 0.25      , 0.16000228,
#        0.22222311, 0.1600002 , 0.22222278, 0.09876538, 0.25      ])

# %%
for k in psf_data.keys():
    plt.figure()
    plt.scatter(psf_coords[:,1], psf_data[k][:])
    plt.title(k)
    plt.show()
    plt.close()

# %%
# eta_target = 0.0987
eta_target = 0.16
mask = (psf_coords[:,0] > eta_target-1e-3) & (psf_coords[:,0] < eta_target+1e-3)
for k in psf_data.keys():
    plt.figure()
    plt.scatter(psf_coords[mask,1], psf_data[k][mask])
    plt.title(k)
    plt.show()
    plt.close()

# %%
for k in psf_data.keys():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(psf_coords[:,0], psf_coords[:,1], psf_data[k])
    ax.set_title(k)
    fig.show()

# %%
for k in psf_data.keys():
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(psf_coords[:,2], psf_coords[:,1], psf_data[k])
    ax.set_title(k)
    fig.show()

# %%
# q, chi, costheta

# %%
pwd
# Out:
# '/nfshome/store01/users/sebastian.khan/projects/eh-lal/compare-ns-co-prec/puck/sk'

# %%
# np.savetxt("psf_phase_x.txt", psf_coords)

# %%
# psf_y = np.array([psf_data[k] for k in psf_data.keys()]).T

# %%
# np.savetxt("psf_phase_y.txt", psf_y)

# %%
# psf_coords = np.loadtxt("psf_phase_x.txt")

# %%
# psf_y = np.loadtxt("psf_phase_y.txt")

# %%
# psf_y.shape

# %%
# plt.figure()
# plt.scatter(psf_coords[:,1], psf_y[:,2])

# %%
# psf_coords[0]

# %%
# myfile = "psf_phase_names.txt"
# with open(myfile, 'w') as f:
#     f.write("\n".join(psf_names))

# %%
# example read
# with open(myfile, 'r') as f:
#     mystring = f.read()
# my_list = mystring.split("\n")
